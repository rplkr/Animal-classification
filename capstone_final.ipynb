# %%
# General Imports
import os
import json
import random
import pandas as pd
import numpy as np
from tqdm import tqdm

import warnings
# Disable warnings
warnings.filterwarnings("ignore")

# TensorFlow and Keras Imports
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from keras.callbacks import ModelCheckpoint, LambdaCallback, EarlyStopping
import keras_tuner as kt

# Sklearn Imports
from sklearn.model_selection import train_test_split

# Image Processing Imports
import cv2
from PIL import Image
from io import BytesIO
from imutils import paths

# Web Scraping Imports
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from requests.exceptions import ConnectionError, Timeout, RequestException

# for Interface
import gradio as gr
import threading

print("Done")
# Out:
# Done

# %%
def extract_images(url_save_path_pairs):
    for url, save_path in url_save_path_pairs:
        response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(response.content, 'html.parser')
        img_tags = soup.find_all('img')
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        image_count = 0
        num_images_downloaded = 0
        i = save_path.split("\\")[-1]
        print(f"For {i}:")
        print("")
        for img_tag in img_tags:
            t = save_path.split("\\")[-1]
            img_url = img_tag.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                img_filename = os.path.basename(urlparse(img_url).path)
                 
                # https://example.com/images/photo.jpg, the path is /images/photo.jpg.
                #os.path.basename('/images/photo.jpg') would return 'photo.jpg'.
                
                try:
                    img_data = requests.get(img_url, headers={'User-Agent': 'Mozilla/5.0'}).content
                    
                    #gives you the raw binary content (bytes) of the response
                    
                    img = Image.open(BytesIO(img_data))
                    
                    #variable contains the raw binary data of an image retrieved from a URL
                    # provides a binary stream interface for reading and writing bytes data.
                    #Image.open() to open the binary image data as an image object.
                    
                    image_count += 1
                    img.save(os.path.join(save_path, os.path.splitext(img_filename)[0] + ".jpg"), "JPEG")
                    print(f"Image saved: {t+str(image_count)+ '.jpg'}")
                    print("----------------")
                    num_images_downloaded += 1
                except (ConnectionError, Timeout, requests.RequestException) as e:
                    print(f"Error")
                except IOError as e:
                    print(f"Error IO")
                except UnidentifiedImageError as e:
                    print("Error UI")
        print(" ")
        print(f"Total number of images downloaded for {i}: {num_images_downloaded}")   
        print("")
        print("=========================================")

Bear=['https://unsplash.com/images/animals/bear',"https://unsplash.com/s/photos/bear","https://www.gettyimages.in/search/2/image?family=creative&phrase=bear","https://pixabay.com/images/search/wild%20bear%20/","https://www.pexels.com/search/wild%20bear/","https://www.dreamstime.com/photos-images/wild-bear.html","https://a-z-animals.com/animals/bear/pictures/"]
Elephant=["https://unsplash.com/images/animals/elephant",'https://unsplash.com/s/photos/Elephant',"https://www.gettyimages.in/photos/elephant?assettype=image&alloweduse=availableforalluses&family=creative&phrase=Elephant&sort=mostpopular","https://pixabay.com/images/search/elephant/","https://www.pexels.com/search/Elephant/","https://www.dreamstime.com/photos-images/elephant.html","https://a-z-animals.com/animals/elephant/pictures/"]
Horse=["https://unsplash.com/images/animals/horse",'https://unsplash.com/s/photos/Horse',"https://www.gettyimages.in/photos/horse?assettype=image&alloweduse=availableforalluses&family=creative&phrase=horse&sort=mostpopular","https://pixabay.com/images/search/Horse/","https://www.pexels.com/search/Horse/","https://www.dreamstime.com/photos-images/Horse.html","https://a-z-animals.com/animals/horse/pictures/"]
Lion=["https://www.pexels.com/search/Lion/", 'https://a-z-animals.com/animals/lion/pictures/', "https://www.dreamstime.com/photos-images/lion.html", "https://unsplash.com/images/animals/lion", "https://unsplash.com/s/photos/Lion", "https://www.gettyimages.in/photos/lion?assettype=image&phrase=Lion&sort=mostpopular&license=rf%2Crm" ,"https://pixabay.com/images/search/lion/"]
Panda=["https://www.pexels.com/search/Panda/",'https://www.dreamstime.com/photos-images/panda.html',"https://unsplash.com/images/animals/panda","https://unsplash.com/s/photos/panda","https://www.gettyimages.in/photos/panda?assettype=image&phrase=Panda&sort=mostpopular&license=rf%2Crm","https://pixabay.com/images/search/panda/"]
Tiger=["https://www.pexels.com/search/Tiger/",'https://a-z-animals.com/animals/tiger/pictures/',"https://www.dreamstime.com/photos-images/tiger.html","https://unsplash.com/images/animals/tiger","https://unsplash.com/s/photos/Tiger","https://www.gettyimages.in/photos/tiger?assettype=image&phrase=Tiger&sort=mostpopular&license=rf%2Crm","https://pixabay.com/images/search/tiger/"]

url_save_path_pairs = [
    
    (Bear[0], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[1], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[2], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[3], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[4], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[5], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
    (Bear[6], r'C:\Users\Raj Rohra\Downloads\animals\Bear'),
  
    (Elephant[0], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[1], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[2], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[3], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[4], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[5], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
    (Elephant[6], r'C:\Users\Raj Rohra\Downloads\animals\Elephant'),
     
    (Horse[0], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[1], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[2], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[3], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[4], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[5], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
    (Horse[6], r'C:\Users\Raj Rohra\Downloads\animals\Horse'),
            
    (Lion[0], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[1], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[2], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[3], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[4], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[5], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),
    (Lion[6], r'C:\Users\Raj Rohra\Downloads\animals\Lion'),       
    
    (Panda[0], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
    (Panda[1], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
    (Panda[2], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
    (Panda[3], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
    (Panda[4], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
    (Panda[5], r'C:\Users\Raj Rohra\Downloads\animals\Panda'),
           
    (Tiger[0], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[1], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[2], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[3], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[4], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[5], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),
    (Tiger[6], r'C:\Users\Raj Rohra\Downloads\animals\Tiger'),       
]

extract_images(url_save_path_pairs)

# %%
DATASET = "main_data"  # this folder contains images on which the model will train

# %%
# initialize the data and labels
print("[INFO] loading images...")
data = []
labels = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(DATASET)))
random.seed(42)
random.shuffle(imagePaths)

# progress bar 
with tqdm(total=len(imagePaths)) as pbar:
    
    # loop over the input images
    for idx, imagePath in enumerate(imagePaths): 
        # load the image, pre-process it, and store it in the data list
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (28, 28))
        image = img_to_array(image)
        data.append(image)

        # extract the class label from the image path and update the
        # labels list
        label = imagePath.split(os.path.sep)[-2]

        if label == "Bear":
            label = 0
        elif label == "Elephant":
            label = 1
        elif label == "Horse":
            label = 2
        elif label == "Panda":
            label = 3
        elif label == "Tiger":
            label = 4
            
            
        labels.append(label)
        
        # update the progressbar
        pbar.update(1)
# Out:
# [INFO] loading images...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1227/1227 [00:04<00:00, 271.14it/s]

# %%
imagePaths
# Out:
# ['main_data\\Bear\\Bear_20_2.jpg',
#  'main_data\\Tiger\\Tiger_14_1.jpg',
#  'main_data\\Tiger\\Tiger_14_2.jpg',
#  'main_data\\Horse\\Horse_24.jpg',
#  'main_data\\Horse\\red-horse-on-pasture.jpg',
#  'main_data\\Bear\\Bear_30_3.jpg',
#  'main_data\\Horse\\Horse_23_1.jpg',
#  'main_data\\Tiger\\Tiger_30.jpeg',
#  'main_data\\Elephant\\elephant-big-nature-wildlife.jpg',
#  'main_data\\Tiger\\Tiger_13_1.jpg',
#  'main_data\\Tiger\\royal-bengal-tiger-768x510.jpg',
#  'main_data\\Elephant\\premium_photo-1666690195791-9b812e5382b7.jpg',
#  'main_data\\Panda\\Panda_6_1.jpg',
#  'main_data\\Tiger\\pexels-photo-572861.jpg',
#  'main_data\\Tiger\\Tigers46.jpg',
#  'main_data\\Panda\\Panda_13_3.jpg',
#  'main_data\\Panda\\Panda_8_4.jpg',
#  'main_data\\Horse\\horse-197199_640.jpg',
#  'main_data\\Horse\\Horses9.jpg',
#  'main_data\\Horse\\Horse_1_3.jpg',
#  'main_data\\Elephant\\Elephant_4_4.jpg',
#  'main_data\\Panda\\Panda_16.jpeg',
#  'main_data\\Panda\\Panda_16_2.jpg',
#  'main_data\\Horse\\Horse_27_1.jpg',
#  'main_data\\Tiger\\snarling-tiger.jpg',
#  'main_data\\Horse\\Horse_21_1.jpg',
#  'main_data\\Panda\\funny-pandas.jpg',
#  'main_data\\Tiger\\Tiger_22_2.jpg',
#  'main_data\\Panda\\Panda_25_1.jpg',
#  'main_data\\Elephant\\Elephant_8.jpeg',
#  'main_data\\Tiger\\Tigers63.jpg',
#  'main_data\\Panda\\Panda_22.jpeg',
#  'main_data\\Elephant\\elephant-isolated.jpg',
#  'main_data\\Bear\\bear_4_3.jpg',
#  'main_data\\Panda\\close-up-giant-panda-in-republic-of-korea.jpg',
#  'main_data\\Panda\\giant-panda-eating-green-bamboo-leaf-44667369.jpg',
#  'main_data\\Panda\\Panda_10_4.jpg',
#  'main_data\\Elephant\\Elephant_20.jpeg',
#  'main_data\\Tiger\\Tigers24.jpg',
#  'main_data\\Horse\\Horse_20_3.jpg',
#  'main_data\\Horse\\Horse_4_3.jpg',
#  'main_data\\Panda\\panda-4461766_640.jpg',
#  'main_data\\Horse\\Horses42.jpg',
#  'main_data\\Horse\\Horse_7_1.jpg',
#  'main_data\\Horse\\thoroughbred-stallion-horse-standing-majestically-in-rural-scene.jpg',
#  'main_data\\Bear\\Bear_9_4.jpg',
#  'main_data\\Panda\\Panda_6_4.jpg',
#  'main_data\\Panda\\giant-panda-ailuropoda-melanoleuca-china-family-ursidae-eating-a-bamboo-branch.jpg',
#  'main_data\\Panda\\Panda_29_3.jpg',
#  'main_data\\Panda\\Panda_4.jpg',
#  'main_data\\Tiger\\royal-tiger-768x479.jpg',
#  'main_data\\Tiger\\Tigers45.jpg',
#  'main_data\\Horse\\Horse_13_1.jpg',
#  'main_data\\Elephant\\big-angry-african-elephant-bull-bush-savanna-wearing-tracking-collar-musth-showing-his-aggression-was-walking-79374054.jpg',
#  'main_data\\Horse\\Horses36.jpg',
#  'main_data\\Elephant\\elephant-114543_640.jpg',
#  'main_data\\Tiger\\tiger-2535888_640.jpg',
#  'main_data\\Panda\\baby-panda-tree-chengdu-research-base-giant-breeding-30966536.jpg',
#  'main_data\\Elephant\\shutterstock_203562340-768x512.jpg',
#  'main_data\\Elephant\\Elephant_27_2.jpg',
#  'main_data\\Tiger\\Tiger_18_3.jpg',
#  'main_data\\Tiger\\prowling-tiger-majestic-looking-camera-49176258.jpg',
#  'main_data\\Bear\\photo-1573920111312-04f1b25c6b85.jpg',
#  'main_data\\Panda\\panda-in-repose.jpg',
#  'main_data\\Horse\\horse6-768x576.jpg',
#  'main_data\\Panda\\giant-panda-25855584.jpg',
#  'main_data\\Horse\\Shire-768x401.jpg',
#  'main_data\\Panda\\giant-panda-baby-cub-in-chengdu-area-china.jpg',
#  'main_data\\Bear\\Bear_29.jpeg',
#  'main_data\\Bear\\Bear_12_3.jpg',
#  'main_data\\Bear\\kodiak-bear-ursus-arctos-middendorffi-adult-with-open-mouth-defensive-posture-alaska.jpg',
#  'main_data\\Elephant\\Elephant_2_3.jpg',
#  'main_data\\Tiger\\Extinct-Animals_-Javan-Tiger-768x401.jpg',
#  'main_data\\Horse\\Horses27.jpg',
#  'main_data\\Panda\\Panda_24_1.jpg',
#  'main_data\\Tiger\\side-view-of-tiger-walking-on-field-bandhavgarh-tiger-reserve-india.jpg',
#  'main_data\\Elephant\\african-elephant-calf.jpg',
#  'main_data\\Elephant\\Elephant_30_3.jpg',
#  'main_data\\Tiger\\pexels-photo-2649841.jpg',
#  'main_data\\Horse\\Horses10.jpg',
#  'main_data\\Bear\\grizzly-bear-ursus-arctos-horribilis-montana-usa-captive-or-controlled-situation.jpg',
#  'main_data\\Elephant\\Elephant_22_1.jpg',
#  'main_data\\Horse\\Horse_28_1.jpg',
#  'main_data\\Tiger\\Tiger_20_2.jpg',
#  'main_data\\Tiger\\Tigers73.jpg',
#  'main_data\\Elephant\\portrait-of-african-elephant-during-safari-trip-in-tanzania.jpg',
#  'main_data\\Horse\\Horse_22_3.jpg',
#  'main_data\\Tiger\\Tiger_1_1.jpg',
#  'main_data\\Horse\\Horse_21_3.jpg',
#  'main_data\\Tiger\\Tiger_26_2.jpg',
#  'main_data\\Horse\\horse-561221_640.jpg',
#  'main_data\\Bear\\Bear_15_1.jpg',
#  'main_data\\Panda\\Panda_8_2.jpg',
#  'main_data\\Elephant\\Elephant_9_2.jpg',
#  'main_data\\Bear\\Bear_3_1.jpg',
#  'main_data\\Panda\\portrait-of-a-giant-panda-eating-bamboo.jpg',
#  'main_data\\Bear\\Bear_29_1.jpg',
#  'main_data\\Bear\\Bear_13.jpeg',
#  'main_data\\Panda\\Panda_9_3.jpg',
#  'main_data\\Panda\\giant-pandas-eating-bamboo.jpg',
#  'main_data\\Horse\\brown-horse-isolated-7487359.jpg',
#  'main_data\\Horse\\Tallest-Horses-Australian-Draught-768x401.jpg',
#  'main_data\\Bear\\Bear_11.jpeg',
#  'main_data\\Panda\\giant-panda-13303258.jpg',
#  'main_data\\Horse\\Horse_6_3.jpg',
#  'main_data\\Panda\\Panda_13_2.jpg',
#  'main_data\\Elephant\\Elephant_29.jpg',
#  'main_data\\Tiger\\Tiger_23_1.jpg',
#  'main_data\\Elephant\\elephant-portrait-up-close-photo-tusks-amboseli-national-park-kenya-50253046.jpg',
#  'main_data\\Bear\\brown-bear-isolated-white-5997424.jpg',
#  'main_data\\Tiger\\Tigers30.jpg',
#  'main_data\\Horse\\pack-horse-in-the-himalayas.jpg',
#  'main_data\\Horse\\Horse_6_4.jpg',
#  'main_data\\Horse\\Horses54.jpg',
#  'main_data\\Tiger\\tiger-panthera-tigris-largest-cat-species-most-recognisable-their-pattern-dark-vertical-stripes-reddish-84739843.jpg',
#  'main_data\\Panda\\Panda_28_1.jpg',
#  'main_data\\Horse\\Horse_30_1.jpg',
#  'main_data\\Panda\\Panda_4_4.jpg',
#  'main_data\\Elephant\\photo-1577638433789-bbdc5bd75251.jpg',
#  'main_data\\Horse\\horse-portrait-motion-black-run-gallop-isolated-white-background-69080302.jpg',
#  'main_data\\Panda\\Panda_3_1.jpg',
#  'main_data\\Bear\\Bear_27_2.jpg',
#  'main_data\\Elephant\\Elephant-Serengeti-768x401.jpg',
#  'main_data\\Panda\\low-angle-view-of-koala-on-tree-berlin-germany.jpg',
#  'main_data\\Elephant\\Elephant_27_4.jpg',
#  'main_data\\Panda\\Panda_29_1.jpg',
#  'main_data\\Tiger\\portrait-bengal-tiger-1-year-old-sitting-10781421.jpg',
#  'main_data\\Elephant\\Elephant_14_2.jpg',
#  'main_data\\Horse\\Horse_1.jpeg',
#  'main_data\\Tiger\\close-up-front-portrait-of-indochinese-tiger-picture-id1073104360-768x401.jpg',
#  'main_data\\Horse\\Horse_21.jpeg',
#  'main_data\\Tiger\\Tigers68.jpg',
#  'main_data\\Tiger\\Tiger_3_2.jpg',
#  'main_data\\Panda\\big-panda-sitting-eating-bamboo-endangered-species-black-and-white-mammal.jpg',
#  'main_data\\Elephant\\Elephant_9_1.jpg',
#  'main_data\\Tiger\\portrait-of-a-royal-bengal-tiger-alert-and-staring-at-the-camera-national-animal-of-bangladesh.jpg',
#  'main_data\\Horse\\Horses33.jpg',
#  'main_data\\Elephant\\Elephant_30.jpeg',
#  'main_data\\Elephant\\Elephant_14.jpeg',
#  'main_data\\Panda\\Panda_3_4.jpg',
#  'main_data\\Panda\\cute-panda-cub-looking-at-camera.jpg',
#  'main_data\\Bear\\animal-4494180_640.jpg',
#  'main_data\\Horse\\photo-1616271939581-591f6a7abb4d.jpg',
#  'main_data\\Horse\\Horse_5_2.jpg',
#  'main_data\\Bear\\Bear_15.jpeg',
#  'main_data\\Bear\\Bear_20_4.jpg',
#  'main_data\\Elephant\\elephant-tusk-ivory-animal-53125.jpg',
#  'main_data\\Tiger\\tiger-stalking-prey-wild-hunting-49176497.jpg',
#  'main_data\\Elephant\\pexels-photo-982021.jpg',
#  'main_data\\Tiger\\Tiger_18.jpeg',
#  'main_data\\Tiger\\Screenshot 2024-05-12 115805.png',
#  'main_data\\Horse\\Horse_2_3.jpg',
#  'main_data\\Tiger\\Tiger_12_2.jpg',
#  'main_data\\Panda\\Panda_10_2.jpg',
#  'main_data\\Panda\\panda-cub-in-a-tree.jpg',
#  'main_data\\Panda\\Panda_15_2.jpg',
#  'main_data\\Panda\\teeth-of-the-giant-panda-ailuropoda-melanoleuca-wolong-nature-preserve-china-family-ursidae.jpg',
#  'main_data\\Horse\\Horses22.jpg',
#  'main_data\\Horse\\pexels-photo-1996338.jpg',
#  'main_data\\Tiger\\Tiger_25_4.jpg',
#  'main_data\\Panda\\Panda_22_3.jpg',
#  'main_data\\Tiger\\close-up-tiger-face-isolated-on-black-background.jpg',
#  'main_data\\Elephant\\Elephant_8_2.jpg',
#  'main_data\\Tiger\\siberian-tiger-running-11134837.jpg',
#  'main_data\\Bear\\Bear_29_2.jpg',
#  'main_data\\Horse\\Horse_30_3.jpg',
#  'main_data\\Tiger\\Tigers27.jpg',
#  'main_data\\Elephant\\Elephant_16_3.jpg',
#  'main_data\\Panda\\cute-panda-eating-bamboo.jpg',
#  'main_data\\Elephant\\pexels-photo-2677849.jpg',
#  'main_data\\Horse\\Tallest-Horses-Belgian-Draft-768x401.jpg',
#  'main_data\\Tiger\\pexels-photo-2642250.jpg',
#  'main_data\\Horse\\Horse_16.jpeg',
#  'main_data\\Panda\\Panda_9_1.jpg',
#  'main_data\\Elephant\\photo-1557178985-891ca9b9b01c.jpg',
#  'main_data\\Elephant\\elephant-washing-in-the-river.jpg',
#  'main_data\\Tiger\\male-adult-bengal-tiger-sleeping-thailand-asia-cat-16611638.jpg',
#  'main_data\\Tiger\\Tigers100.jpg',
#  'main_data\\Bear\\bear_8_3.jpg',
#  'main_data\\Panda\\panda-8171354_1280.jpg',
#  'main_data\\Horse\\Horse_25_4.jpg',
#  'main_data\\Panda\\cute-panda-bear-eating-bamboo-close-up.jpg',
#  'main_data\\Tiger\\portrait-of-angry-tiger-jakarta-indonesia.jpg',
#  'main_data\\Panda\\giant-panda-eating-bamboo.jpg',
#  'main_data\\Elephant\\Elephant_11_2.jpg',
#  'main_data\\Tiger\\Tigers96.jpg',
#  'main_data\\Bear\\pexels-photo-7183267.jpg',
#  'main_data\\Panda\\Panda_7.jpg',
#  'main_data\\Tiger\\tiger-portrait-close-up-shot-head-55930576.jpg',
#  'main_data\\Bear\\bear-768x512.jpg',
#  'main_data\\Horse\\Most-Expensive-Horses-Andalusian-768x401.jpg',
#  'main_data\\Bear\\Bear_27_1.jpg',
#  'main_data\\Panda\\front-view-of-an-adult-panda-walking-on-the-ground.jpg',
#  'main_data\\Horse\\Horse_9_1.jpg',
#  'main_data\\Tiger\\Tiger_14_4.jpg',
#  'main_data\\Horse\\Most-Expensive-Horses-Akhal-Teke-768x401.jpg',
#  'main_data\\Tiger\\Tiger_19_1.jpg',
#  'main_data\\Tiger\\Tigers92.jpg',
#  'main_data\\Tiger\\Tigers102.jpg',
#  'main_data\\Bear\\bear_1_4.jpg',
#  'main_data\\Panda\\Panda_28_3.jpg',
#  'main_data\\Tiger\\Tiger_23_3.jpg',
#  'main_data\\Panda\\Panda_19_3.jpg',
#  'main_data\\Horse\\horse5-768x576.jpg',
#  'main_data\\Elephant\\Elephant_9.jpeg',
#  'main_data\\Bear\\Bear_16_1.jpg',
#  'main_data\\Elephant\\elephants-at-a-waterhole-in-botswana-khwai-private-reserve.jpg',
#  'main_data\\Panda\\giant-panda-bear.jpg',
#  'main_data\\Panda\\Panda_1_2.jpg',
#  'main_data\\Horse\\photo-1450052590821-8bf91254a353.jpg',
#  'main_data\\Tiger\\Tiger_21.jpeg',
#  'main_data\\Panda\\great-pandas-looking-at-the-camera-chengdu-sichuan-china.jpg',
#  'main_data\\Horse\\Horses13.jpg',
#  'main_data\\Bear\\Bear_5_3.jpg',
#  'main_data\\Bear\\brown-bear-portrait.jpg',
#  'main_data\\Tiger\\panthera-tigris-altaica-tiger-siberian-amurtiger-162203.jpg',
#  'main_data\\Panda\\Panda_7_3.jpg',
#  'main_data\\Elephant\\photo-1544211412-2a32426e7fd5.jpg',
#  'main_data\\Tiger\\Tiger_14_3.jpg',
#  'main_data\\Horse\\Horse_16_3.jpg',
#  'main_data\\Horse\\Horse_30.jpeg',
#  'main_data\\Panda\\Panda_6_3.jpg',
#  'main_data\\Tiger\\Tiger_23.jpeg',
#  'main_data\\Horse\\Horse_28_2.jpg',
#  'main_data\\Bear\\approach.jpg',
#  'main_data\\Horse\\Horse_15_4.jpg',
#  'main_data\\Tiger\\Tigers35.jpg',
#  'main_data\\Horse\\Horse_17_3.jpg',
#  'main_data\\Horse\\Horse-Running-768x329.jpg',
#  'main_data\\Horse\\brown-horse.jpg',
#  'main_data\\Tiger\\Tiger_15_1.jpg',
#  'main_data\\Elephant\\elephant-large-san-diego-zoos-wildlife-safari-park-32161382.jpg',
#  'main_data\\Horse\\arabian-horse-13525215.jpg',
#  'main_data\\Panda\\Panda_17_1.jpg',
#  'main_data\\Tiger\\Tigers32.jpg',
#  'main_data\\Horse\\Horse_13_3.jpg',
#  'main_data\\Horse\\Horse_12_2.jpg',
#  'main_data\\Tiger\\Tiger_7_2.jpg',
#  'main_data\\Tiger\\Tigers59.jpg',
#  'main_data\\Tiger\\tiger-resting-on-rocky-outcrop-close-up.jpg',
#  'main_data\\Panda\\Panda_3_3.jpg',
#  'main_data\\Bear\\Bear_12_2.jpg',
#  'main_data\\Horse\\Horse_17_2.jpg',
#  'main_data\\Bear\\Bear_3_2.jpg',
#  'main_data\\Elephant\\Elephant_16_1.jpg',
#  'main_data\\Tiger\\tiger-sitting-2320900.jpg',
#  'main_data\\Elephant\\Elephant_12.jpg',
#  'main_data\\Tiger\\Tiger_26.jpeg',
#  'main_data\\Horse\\Best-Horses-Quarter-Horse-768x401.jpg',
#  'main_data\\Panda\\Panda_14.jpg',
#  'main_data\\Horse\\Horse_26_1.jpg',
#  'main_data\\Elephant\\Elephant_18_3.jpg',
#  'main_data\\Elephant\\Elephant_17_1.jpg',
#  'main_data\\Tiger\\growling-tiger-isolated-white-background-furious-tiger-119360721.jpg',
#  'main_data\\Elephant\\Elephant_23_1.jpg',
#  'main_data\\Horse\\Horse_3.jpg',
#  'main_data\\Bear\\Bear_26_3.jpg',
#  'main_data\\Tiger\\tiger-in-a-forest.jpg',
#  'main_data\\Elephant\\photo-1610957735048-538a729f16ab.jpg',
#  'main_data\\Horse\\Horse_18_1.jpg',
#  'main_data\\Tiger\\Tigers51.jpg',
#  'main_data\\Panda\\pexels-photo-11909034.jpg',
#  'main_data\\Elephant\\Heaviest-Animals_-Elephants-768x401.jpg',
#  'main_data\\Elephant\\roaring-asian-elephant-detail-36478319.jpg',
#  'main_data\\Panda\\photo-1566487097168-e91a4f38bee2.jpg',
#  'main_data\\Elephant\\Elephant_26_1.jpg',
#  'main_data\\Bear\\grizzly-bear-arctos-ursus-closeup-27227267.jpg',
#  'main_data\\Tiger\\sumatran-tiger-critically-endangered-species-around-left-wild-global-day-july-th-daseep-three-year-42810648.jpg',
#  'main_data\\Elephant\\asian-elephant-familys-walking-4-17291857.jpg',
#  'main_data\\Elephant\\Elephant_21_3.jpg',
#  'main_data\\Horse\\Horses65.jpg',
#  'main_data\\Panda\\pexels-photo-14925845.jpg',
#  'main_data\\Horse\\photo-1583002971061-b36b6f667766.jpg',
#  'main_data\\Bear\\pexels-photo-13685856.jpg',
#  'main_data\\Bear\\a-brown-bear-is-walking-through-water-in-front-of-grass.jpg',
#  'main_data\\Tiger\\tiger-1868911_640.jpg',
#  'main_data\\Elephant\\Elephant_6.jpg',
#  'main_data\\Bear\\Bear_5_2.jpg',
#  'main_data\\Horse\\horse-3718301.jpg',
#  'main_data\\Horse\\Best-Horses-Lipizzan-768x401.jpg',
#  'main_data\\Panda\\Panda_15_1.jpg',
#  'main_data\\Horse\\Tallest-Animals_-Shire-Horse-768x401.jpg',
#  'main_data\\Panda\\giant-panda-12560704.jpg',
#  'main_data\\Horse\\Horses50.jpg',
#  'main_data\\Bear\\bear_1_2.jpg',
#  'main_data\\Panda\\giant-panda-cub-sleeping-chengdu-china-76541308.jpg',
#  'main_data\\Bear\\brown-bear-cub-running-12797580.jpg',
#  'main_data\\Panda\\baby-panda-climbing-tree-national-zoo-washington-dc-39698748.jpg',
#  'main_data\\Panda\\Panda_27.jpeg',
#  'main_data\\Elephant\\male-asian-elephant-isolated-on-white-background.jpg',
#  'main_data\\Bear\\grizzly-bear-standing-and-roaring.jpg',
#  'main_data\\Panda\\Panda_1_1.jpg',
#  'main_data\\Bear\\Bear_13_4.jpg',
#  'main_data\\Elephant\\elephant-portrait-967391.jpg',
#  'main_data\\Elephant\\elephant-isolated-12229701.jpg',
#  'main_data\\Elephant\\african-elephant-isolated-large-white-background-91136393.jpg',
#  'main_data\\Panda\\panda-white-background-49936911.jpg',
#  'main_data\\Panda\\Panda_18_4.jpg',
#  'main_data\\Horse\\pexels-photo-1996337.jpg',
#  'main_data\\Bear\\Bear_21_3.jpg',
#  'main_data\\Elephant\\Elephant_4.jpeg',
#  'main_data\\Tiger\\tiger-2923186_640.jpg',
#  'main_data\\Tiger\\Tigers84.jpg',
#  'main_data\\Bear\\Bear_9_3.jpg',
#  'main_data\\Tiger\\Tigers80.jpg',
#  'main_data\\Panda\\giant-panda-sitting-rock-42501757.jpg',
#  'main_data\\Horse\\Horse_13.jpeg',
#  'main_data\\Tiger\\Tigers34.jpg',
#  'main_data\\Bear\\Bear_27_3.jpg',
#  'main_data\\Bear\\Bear_20.jpeg',
#  'main_data\\Horse\\fohlen-auf-der-wiese-im-galopp.jpg',
#  'main_data\\Panda\\Panda_30_2.jpg',
#  'main_data\\Horse\\Horse_27_2.jpg',
#  'main_data\\Horse\\horse-4-768x497.jpg',
#  'main_data\\Panda\\baby-panda-tree-chengdu-research-base-giant-breeding-30774508.jpg',
#  'main_data\\Elephant\\Elephant_1_1.jpg',
#  'main_data\\Tiger\\tiger2-768x514.jpg',
#  'main_data\\Horse\\Tallest-Horses-Clydesdale-768x401.jpg',
#  'main_data\\Horse\\Horse_20_2.jpg',
#  'main_data\\Bear\\brown-bear-5584413.jpg',
#  'main_data\\Panda\\Panda_15.jpg',
#  'main_data\\Panda\\Panda_17_3.jpg',
#  'main_data\\Elephant\\african-elephant-amboseli-2584709.jpg',
#  'main_data\\Elephant\\Elephant_17.jpg',
#  'main_data\\Panda\\Panda_27_2.jpg',
#  'main_data\\Tiger\\Tiger_19_2.jpg',
#  'main_data\\Panda\\Panda_30_4.jpg',
#  'main_data\\Panda\\photo-1584315918341-a6017ae8869f.jpg',
#  'main_data\\Bear\\morning-bear-yoga.jpg',
#  'main_data\\Panda\\giant-panda-4-months-ailuropoda-melanoleuca-7981518.jpg',
#  'main_data\\Bear\\Bear_6_2.jpg',
#  'main_data\\Horse\\Horse_29.jpeg',
#  'main_data\\Panda\\giant-panda-sitting-against-white-background-11290476.jpg',
#  'main_data\\Elephant\\african-elephant-loxodonta-africana-female-white-background-35980917.jpg',
#  'main_data\\Elephant\\Elephant_8_1.jpg',
#  'main_data\\Bear\\Bear_21_2.jpg',
#  'main_data\\Elephant\\elephant-matriarch-cow-leading-a-herd.jpg',
#  'main_data\\Elephant\\Elephant_15_1.jpg',
#  'main_data\\Bear\\Bear_20_3.jpg',
#  'main_data\\Tiger\\Tiger_24_2.jpg',
#  'main_data\\Horse\\white-horse-isolated-trots-9420630.jpg',
#  'main_data\\Panda\\Panda_18_3.jpg',
#  'main_data\\Tiger\\tiger-2791980_640.jpg',
#  'main_data\\Elephant\\photo-1551807964-90472ed058b3.jpg',
#  'main_data\\Horse\\Horses16.jpg',
#  'main_data\\Horse\\Horses41.jpg',
#  'main_data\\Elephant\\Elephant_23.jpeg',
#  'main_data\\Horse\\Tallest-Horses-American-Cream-Draft-768x401.jpg',
#  'main_data\\Tiger\\Tiger_6_2.jpg',
#  'main_data\\Tiger\\Tiger_28.jpeg',
#  'main_data\\Panda\\Panda_21.jpg',
#  'main_data\\Panda\\free-photo-of-panda-sitting-on-branch.jpg',
#  'main_data\\Tiger\\tiger-165189_640.jpg',
#  'main_data\\Tiger\\tiger-formal-portrait-12480138.jpg',
#  'main_data\\Horse\\Horses52.jpg',
#  'main_data\\Bear\\grizzly-bear.jpg',
#  'main_data\\Elephant\\running-african-elephant.jpg',
#  'main_data\\Panda\\close-up-of-a-panda-holding-a-stick.jpg',
#  'main_data\\Tiger\\Tigers97.jpg',
#  'main_data\\Bear\\grizzly-bear-boar-12598378.jpg',
#  'main_data\\Tiger\\Tiger_6_4.jpg',
#  'main_data\\Panda\\Panda_3_2.jpg',
#  'main_data\\Horse\\Horse_3_2.jpg',
#  'main_data\\Bear\\Bear_11_3.jpg',
#  'main_data\\Horse\\Most-Expensive-Horses-Dutch-Warmblood-768x401.jpg',
#  'main_data\\Bear\\bear-1315128_640.jpg',
#  'main_data\\Elephant\\Elephant-male-768x401.jpg',
#  'main_data\\Bear\\brown-bear-5696452.jpg',
#  'main_data\\Panda\\cute-giant-panda-bear-posing-camera-17117324.jpg',
#  'main_data\\Bear\\bear_1.jpg',
#  'main_data\\Tiger\\pexels-photo-5745312.jpg',
#  'main_data\\Bear\\grizzly-bear-isolated.jpg',
#  'main_data\\Horse\\Horse_18.jpeg',
#  'main_data\\Panda\\closeup-of-an-adorable-panda-lying-on-a-big-rock-in-the-forest.jpg',
#  'main_data\\Elephant\\Elephant_9_3.jpg',
#  'main_data\\Elephant\\male-african-elephant-in-okavango-delta-botswana-africa.jpg',
#  'main_data\\Horse\\Horse_24_1.jpg',
#  'main_data\\Tiger\\tiger-1975790_640.jpg',
#  'main_data\\Panda\\giant-panda-6-months-ailuropoda-melanoleuca-7980886.jpg',
#  'main_data\\Elephant\\photo-1575187105891-be9b5d30cecd.jpg',
#  'main_data\\Panda\\free-photo-of-panda-bear-sitting-on-ground.jpg',
#  'main_data\\Tiger\\Tigers49.jpg',
#  'main_data\\Elephant\\Elephant_2_1.jpg',
#  'main_data\\Elephant\\photo-1509587837663-52b8687980c5.jpg',
#  'main_data\\Horse\\Clydesdales-768x401.jpg',
#  'main_data\\Panda\\photo-1622892735236-a3c8f017d45e.jpg',
#  'main_data\\Bear\\bear1.jpg',
#  'main_data\\Elephant\\large-bull-elephant.jpg',
#  'main_data\\Tiger\\tiger-stands-on-a-rock-against-the-background-of-the-evening-mountain.jpg',
#  'main_data\\Tiger\\tiger-13723927.jpg',
#  'main_data\\Bear\\brown-bear-view-taiga-forest-finland-93579526.jpg',
#  'main_data\\Horse\\Horse_27_3.jpg',
#  'main_data\\Panda\\pexels-photo-14925846.jpg',
#  'main_data\\Elephant\\Elephant_20_1.jpg',
#  'main_data\\Tiger\\Tiger_25.jpg',
#  'main_data\\Horse\\horse-8472924_640.jpg',
#  'main_data\\Horse\\horse-5836459_640.jpg',
#  'main_data\\Horse\\Tallest-Horses-Dutch-Draft-768x401.jpg',
#  'main_data\\Elephant\\photo-1536797843593-ec2832810622.jpg',
#  'main_data\\Tiger\\Tigers75.jpg',
#  'main_data\\Elephant\\Elephant-Africa-768x401.jpg',
#  'main_data\\Panda\\Panda_24.jpeg',
#  'main_data\\Horse\\Tallest-Horses-header-768x401.jpg',
#  'main_data\\Panda\\Panda_6.jpg',
#  'main_data\\Elephant\\Elephant_10_2.jpg',
#  'main_data\\Elephant\\Elephant_8_3.jpg',
#  'main_data\\Panda\\Panda_25_2.jpg',
#  'main_data\\Horse\\Horse_4_1.jpg',
#  'main_data\\Tiger\\Tiger_6_1.jpg',
#  'main_data\\Elephant\\elephant-on-white-backgroud.jpg',
#  'main_data\\Elephant\\Elephant_15_3.jpg',
#  'main_data\\Bear\\bear_8_4.jpg',
#  'main_data\\Horse\\pexels-photo-629139.jpg',
#  'main_data\\Horse\\pexels-photo-459124.jpg',
#  'main_data\\Panda\\giant-panda-bear-eating-bamboo.jpg',
#  'main_data\\Panda\\panda-isolated-white-clipping-path-90440776.jpg',
#  'main_data\\Tiger\\Tiger_10.jpg',
#  'main_data\\Elephant\\Elephant_24_1.jpg',
#  'main_data\\Elephant\\elephant-waterhole-image-eye-level-view-midday-underground-hide-110683576.jpg',
#  'main_data\\Tiger\\Tigers65.jpg',
#  'main_data\\Elephant\\Elephant_22_3.jpg',
#  'main_data\\Panda\\Panda_21_3.jpg',
#  'main_data\\Horse\\Horse_10.jpg',
#  'main_data\\Panda\\giant-panda.jpg',
#  'main_data\\Panda\\dreaming-panda.jpg',
#  'main_data\\Tiger\\Tiger_2.jpg',
#  'main_data\\Panda\\giant-panda-18-months-ailuropoda-melanoleuca-8552514.jpg',
#  'main_data\\Elephant\\front-view-of-an-african-elephant.jpg',
#  'main_data\\Horse\\Horse_28.jpeg',
#  'main_data\\Tiger\\Tiger_9_4.jpg',
#  'main_data\\Bear\\bear-white-10895395.jpg',
#  'main_data\\Elephant\\Elephant_28.jpeg',
#  'main_data\\Horse\\horse-running-on-a-track-in-motion.jpg',
#  'main_data\\Panda\\Panda_25_3.jpg',
#  'main_data\\Tiger\\Tiger_19_3.jpg',
#  'main_data\\Panda\\Panda_27_1.jpg',
#  'main_data\\Horse\\Horses51.jpg',
#  'main_data\\Tiger\\Tiger_26_1.jpg',
#  'main_data\\Horse\\Horses31.jpg',
#  'main_data\\Bear\\european-brown-bear-ursus-arctos.jpg',
#  'main_data\\Tiger\\Tiger_15.jpeg',
#  'main_data\\Panda\\Panda_5_2.jpg',
#  'main_data\\Bear\\bear_4_4.jpg',
#  'main_data\\Horse\\horse-stilton-a-hunter-19th-century.jpg',
#  'main_data\\Tiger\\the-head-of-a-tiger.jpg',
#  'main_data\\Panda\\Panda_5_3.jpg',
#  'main_data\\Panda\\free-photo-of-close-up-of-panda.jpg',
#  'main_data\\Horse\\Horse_4_4.jpg',
#  'main_data\\Tiger\\Tiger_9_1.jpg',
#  'main_data\\Bear\\premium_photo-1664303915481-f4a7bbc021d4.jpg',
#  'main_data\\Panda\\Panda_19_4.jpg',
#  'main_data\\Elephant\\elephant-8253639_1280.jpg',
#  'main_data\\Panda\\Panda_29_4.jpg',
#  'main_data\\Panda\\giant-panda-isolated-white-background-giant-pandas-no-longer-endangered-species-panda-isolated-white-background-123945511.jpg',
#  'main_data\\Elephant\\Elephant_21_1.jpg',
#  'main_data\\Tiger\\Tigers86.jpg',
#  'main_data\\Horse\\horse-5-768x641.jpg',
#  'main_data\\Tiger\\tiger-6775284.jpg',
#  'main_data\\Tiger\\Tiger_9_2.jpg',
#  'main_data\\Tiger\\tiger-11566398.jpg',
#  'main_data\\Bear\\Bear_26_1.jpg',
#  'main_data\\Panda\\baby-giant-panda-on-the-tree.jpg',
#  'main_data\\Bear\\brown-bear-portrait-in-alaska.jpg',
#  'main_data\\Panda\\Panda_10_3.jpg',
#  'main_data\\Tiger\\Tiger_3_1.jpg',
#  'main_data\\Tiger\\tiger-cub-tiger-cub-big-cat-64152.jpg',
#  'main_data\\Tiger\\Tiger_13_3.jpg',
#  'main_data\\Elephant\\pexels-photo-133394.jpg',
#  'main_data\\Panda\\Panda_5_1.jpg',
#  'main_data\\Horse\\Horse_30_4.jpg',
#  'main_data\\Elephant\\Elephant_21_2.jpg',
#  'main_data\\Tiger\\Tigers106.jpg',
#  'main_data\\Elephant\\portrait-of-old-elephant-among-trees.jpg',
#  'main_data\\Elephant\\Elephant_2_2.jpg',
#  'main_data\\Horse\\Horse_19_2.jpg',
#  'main_data\\Panda\\photo-1613884175576-8b33a3d3cdd7.jpg',
#  'main_data\\Panda\\Panda_9_2.jpg',
#  'main_data\\Tiger\\Tigers54.jpg',
#  'main_data\\Tiger\\sleeping-tiger.jpg',
#  'main_data\\Tiger\\Tiger_12_4.jpg',
#  'main_data\\Elephant\\pexels-photo-2499271.jpg',
#  'main_data\\Bear\\bear-1283347_640.jpg',
#  'main_data\\Tiger\\amur-tiger-is-walking-towards-the-camera-on-isolated-background.jpg',
#  'main_data\\Bear\\Bear_9_1.jpg',
#  'main_data\\Tiger\\Tiger_17_3.jpg',
#  'main_data\\Elephant\\Elephant_20_4.jpg',
#  'main_data\\Tiger\\Tigers89.jpg',
#  'main_data\\Horse\\black-friesian-horse-gallops-hill-23981811.jpg',
#  'main_data\\Elephant\\african-elephant-side-view-isolated-white-20138632.jpg',
#  'main_data\\Elephant\\Elephant_1.jpeg',
#  'main_data\\Elephant\\Elephant_18_4.jpg',
#  'main_data\\Tiger\\tiger-white-background-isolate-full-body.jpg',
#  'main_data\\Horse\\pexels-photo-235894.jpg',
#  'main_data\\Tiger\\tiger-portrait-horizontal-11392212.jpg',
#  'main_data\\Panda\\Panda_18_1.jpg',
#  'main_data\\Horse\\Horse_11_2.jpg',
#  'main_data\\Horse\\Horses53.jpg',
#  'main_data\\Elephant\\Deadliest-Animal-in-the-World_-Elephants-768x401.jpg',
#  'main_data\\Elephant\\bellowing-elephant-in-the-desert.jpg',
#  'main_data\\Elephant\\Elephant_27.jpeg',
#  'main_data\\Bear\\Bear_21.jpeg',
#  'main_data\\Tiger\\tiger-5363655.jpg',
#  'main_data\\Horse\\Horses71.jpg',
#  'main_data\\Horse\\How-long-do-horses-live_-American-Quarter-Horse-768x401.jpg',
#  'main_data\\Elephant\\Elephant_29_3.jpg',
#  'main_data\\Elephant\\Elephant-Loxodonta-Africana-isolated-768x512.jpg',
#  'main_data\\Bear\\Bear_16.jpeg',
#  'main_data\\Elephant\\road-block.jpg',
#  'main_data\\Elephant\\Elephant_6_2.jpg',
#  'main_data\\Horse\\Horse_26.jpeg',
#  'main_data\\Tiger\\roaring-tiger-with-motion-blur.jpg',
#  'main_data\\Bear\\brown-bear-kuhmo-finland.jpg',
#  'main_data\\Panda\\Panda_10_1.jpg',
#  'main_data\\Bear\\bear_4.jpg',
#  'main_data\\Elephant\\Elephant_23_3.jpg',
#  'main_data\\Tiger\\Tiger_28_1.jpg',
#  'main_data\\Panda\\giant-panda-bear-waving-hello-17031886.jpg',
#  'main_data\\Elephant\\side-view-of-elephant-calf-walking-on-grassy-field-near-lakhanpur-chungi-india.jpg',
#  'main_data\\Elephant\\photo-1557050543-4d5f4e07ef46.jpg',
#  'main_data\\Elephant\\african-elephant-isolated-20144018.jpg',
#  'main_data\\Bear\\Bear_17_1.jpg',
#  'main_data\\Tiger\\approaching-tiger.jpg',
#  'main_data\\Tiger\\tiger-beautiful-asian-zoo-56681971.jpg',
#  'main_data\\Bear\\photo-1601293058843-f34e8dd9ccfd.jpg',
#  'main_data\\Tiger\\pexels-photo-792381.jpg',
#  'main_data\\Bear\\premium_photo-1664302930577-bfa333b6ae86.jpg',
#  'main_data\\Elephant\\pexels-photo-3739325.jpg',
#  'main_data\\Tiger\\Tigers41.jpg',
#  'main_data\\Panda\\panda-eating.jpg',
#  'main_data\\Elephant\\Elephant_19_1.jpg',
#  'main_data\\Bear\\brown-bear-8-years-old-walking-15287536.jpg',
#  'main_data\\Panda\\Panda_14_3.jpg',
#  'main_data\\Bear\\brown-bear-walks-among-the-cotton-grass.jpg',
#  'main_data\\Tiger\\Tiger_22.jpg',
#  'main_data\\Horse\\Irish-Draught-768x401.jpg',
#  'main_data\\Horse\\Horses58.jpg',
#  'main_data\\Panda\\Panda_2_3.jpg',
#  'main_data\\Horse\\Vladimir-Draft-Horse-768x401.jpg',
#  'main_data\\Bear\\Bear_20_1.jpg',
#  'main_data\\Bear\\Bear_22_2.jpg',
#  'main_data\\Panda\\giant-panda-sitting-against-white-background-10937828.jpg',
#  'main_data\\Tiger\\Tigers56.jpg',
#  'main_data\\Panda\\Panda_2_1.jpg',
#  'main_data\\Bear\\Bear_28_2.jpg',
#  'main_data\\Bear\\Bear_15_2.jpg',
#  'main_data\\Tiger\\sumatran-tiger-14836831.jpg',
#  'main_data\\Panda\\pexels-photo-4062907.jpg',
#  'main_data\\Elephant\\Elephant_26_3.jpg',
#  'main_data\\Horse\\Horse_10_3.jpg',
#  'main_data\\Elephant\\Elephant_4_2.jpg',
#  'main_data\\Panda\\giant-panda-eating-bamboo-chengdu-china-bear-38787980.jpg',
#  'main_data\\Elephant\\elephant-bathing-nepal-taking-bath-river-chitwan-national-park-41681311.jpg',
#  'main_data\\Panda\\Panda_14_1.jpg',
#  'main_data\\Tiger\\Tiger_17_2.jpg',
#  'main_data\\Elephant\\Elephant_17_3.jpg',
#  'main_data\\Elephant\\close-up-of-indian-asian-elephant-on-field-nilgiris-tamil-nadu-india.jpg',
#  'main_data\\Tiger\\tiger-3424791_640.jpg',
#  'main_data\\Elephant\\Elephant_28_2.jpg',
#  'main_data\\Horse\\pexels-photo-1996332.jpg',
#  'main_data\\Tiger\\close-up-of-sumatran-tiger.jpg',
#  'main_data\\Horse\\Horse_1_1.jpg',
#  'main_data\\Tiger\\Tiger_7.jpeg',
#  'main_data\\Tiger\\Tiger_4_1.jpg',
#  'main_data\\Bear\\alaskan-brown-bear-11198780.jpg',
#  'main_data\\Panda\\giant-panda-6-months-ailuropoda-melanoleuca-7980870.jpg',
#  'main_data\\Elephant\\shutterstock_1171127365-768x512.jpg',
#  'main_data\\Bear\\Bear_17_2.jpg',
#  'main_data\\Tiger\\Tigers94.jpg',
#  'main_data\\Panda\\Panda_13_1.jpg',
#  'main_data\\Horse\\Horse_20_1.jpg',
#  'main_data\\Bear\\premium_photo-1664298010187-091137b9e296.jpg',
#  'main_data\\Horse\\Belgians-768x401.jpg',
#  'main_data\\Elephant\\elephant-bathing-kerala-india-cute-31669917.jpg',
#  'main_data\\Panda\\photo-1564349683136-77e08dba1ef7.jpg',
#  'main_data\\Bear\\Bear_2.jpeg',
#  'main_data\\Tiger\\Tiger_20.jpeg',
#  'main_data\\Tiger\\stalker.jpg',
#  'main_data\\Elephant\\Elephant_30_2.jpg',
#  'main_data\\Tiger\\Tiger_6_3.jpg',
#  'main_data\\Horse\\Horse_25_1.jpg',
#  'main_data\\Elephant\\Elephant_19_3.jpg',
#  'main_data\\Horse\\Horses12.jpg',
#  'main_data\\Panda\\Panda_18_2.jpg',
#  'main_data\\Panda\\pexels-photo-3608263.jpg',
#  'main_data\\Tiger\\Tiger_18_2.jpg',
#  'main_data\\Elephant\\a-lonely-looking-elephant-all-by-himself.jpg',
#  'main_data\\Elephant\\elephant-trunk-and-head-against-white-background.jpg',
#  'main_data\\Tiger\\Tigers82.jpg',
#  'main_data\\Tiger\\Tiger_11.jpg',
#  'main_data\\Tiger\\Tiger_30_2.jpg',
#  'main_data\\Horse\\pexels-photo-1996330.jpg',
#  'main_data\\Bear\\Bear_15_3.jpg',
#  'main_data\\Elephant\\premium_photo-1669740462316-60cf425ba319.jpg',
#  'main_data\\Panda\\Panda_12_3.jpg',
#  'main_data\\Elephant\\Elephant_16_2.jpg',
#  'main_data\\Bear\\Bear_30.jpeg',
#  'main_data\\Horse\\Emotional-Support-Animals-Miniature-Horse-768x401.jpg',
#  'main_data\\Horse\\Horse_20.jpeg',
#  'main_data\\Tiger\\Tiger_12_3.jpg',
#  'main_data\\Panda\\close-up-happy-panda-fu-bao.jpg',
#  'main_data\\Horse\\Best-Horses-Dutch-Warmblood-768x401.jpg',
#  'main_data\\Panda\\panda-eating-bamboo.jpg',
#  'main_data\\Tiger\\photo-1549480017-d76466a4b7e8.jpg',
#  'main_data\\Elephant\\Elephant_18_2.jpg',
#  'main_data\\Bear\\oso.jpg',
#  'main_data\\Elephant\\photo-1619111712102-8273abfea0aa.jpg',
#  'main_data\\Elephant\\Elephant_21.jpg',
#  'main_data\\Bear\\kodiak-grizzly-bears.jpg',
#  'main_data\\Tiger\\Tigers44.jpg',
#  'main_data\\Tiger\\pexels-photo-2541239.jpg',
#  'main_data\\Tiger\\Tiger_22_1.jpg',
#  'main_data\\Tiger\\bengal-tiger-on-a-tree-wildlife-shot.jpg',
#  'main_data\\Panda\\Panda_12_2.jpg',
#  'main_data\\Panda\\giant-panda-4-months-ailuropoda-melanoleuca-8193857.jpg',
#  'main_data\\Horse\\photo-1553284965-5dd8352ff1bd.jpg',
#  'main_data\\Tiger\\Tiger_17_1.jpg',
#  'main_data\\Bear\\Bear_9_2.jpg',
#  'main_data\\Horse\\Horse_15.jpg',
#  'main_data\\Elephant\\Elephant_30_4.jpg',
#  'main_data\\Panda\\panda-portrait-giant-bear-rain-forest-eating-bamboo-58514796.jpg',
#  'main_data\\Horse\\Horse_24_2.jpg',
#  'main_data\\Horse\\Horse_4.jpg',
#  'main_data\\Tiger\\Tiger_2_2.jpg',
#  'main_data\\Elephant\\Elephant_24_3.jpg',
#  'main_data\\Elephant\\Elephant_28_1.jpg',
#  'main_data\\Tiger\\Tigers103.jpg',
#  'main_data\\Tiger\\photo-1602612639468-cd507b1cada9.jpg',
#  'main_data\\Bear\\photo-1561127954-65393e6644d1.jpg',
#  'main_data\\Horse\\Horse_16_1.jpg',
#  'main_data\\Panda\\Panda_1.jpeg',
#  'main_data\\Horse\\Horse_11_4.jpg',
#  'main_data\\Horse\\Horse_29_1.jpg',
#  'main_data\\Horse\\beautiful-red-horse-portrait-black-background-73308573.jpg',
#  'main_data\\Tiger\\Tiger_24.jpeg',
#  'main_data\\Elephant\\african-elephant-on-white-background.jpg',
#  'main_data\\Panda\\yongin-south-korea-giant-chinese-panda-ai-bao-eats-bamboo-at-everland-amusement-park-on-april.jpg',
#  'main_data\\Horse\\Horses28.jpg',
#  'main_data\\Tiger\\Tiger_1.jpg',
#  'main_data\\Horse\\horse-8008038_640.jpg',
#  'main_data\\Bear\\front-view-of-brown-bear-isolated-on-black-background-portrait-of-kamchatka-bear.jpg',
#  'main_data\\Horse\\Horse_18_4.jpg',
#  'main_data\\Tiger\\Tigers95.jpg',
#  'main_data\\Panda\\Panda_8_1.jpg',
#  'main_data\\Tiger\\close-up-view-siberian-tiger-panthera-tigris-altaica-70658676.jpg',
#  'main_data\\Tiger\\Tiger_11_2.jpg',
#  'main_data\\Horse\\Horse_1_4.jpg',
#  'main_data\\Horse\\Horse_3_1.jpg',
#  'main_data\\Elephant\\Elephant-header-2-768x329.jpg',
#  'main_data\\Tiger\\bengal-tiger.jpg',
#  'main_data\\Tiger\\photo-1618142990632-1afb1bd67e7c.jpg',
#  'main_data\\Panda\\giant-panda-6-months-ailuropoda-melanoleuca-7980917.jpg',
#  'main_data\\Bear\\Bear_11_1.jpg',
#  'main_data\\Panda\\a-photo-of-female-giant-panda-mei-xiang-in-the-grass-of-her-enclosure.jpg',
#  'main_data\\Elephant\\Elephant_23_4.jpg',
#  'main_data\\Panda\\close-up-of-cute-panda-pulling-a-face.jpg',
#  'main_data\\Horse\\Horse_26_3.jpg',
#  'main_data\\Tiger\\tiger-12434373.jpg',
#  'main_data\\Elephant\\Elephant_13_2.jpg',
#  'main_data\\Horse\\Horses55.jpg',
#  'main_data\\Tiger\\pexels-photo-302304.jpg',
#  'main_data\\Horse\\Comtois-Horse-768x401.jpg',
#  'main_data\\Tiger\\sumatrean-tiger.jpg',
#  'main_data\\Panda\\panda-19719110.jpg',
#  'main_data\\Horse\\arabian-horse.jpg',
#  'main_data\\Horse\\Horse_22.jpeg',
#  'main_data\\Tiger\\Tiger_1_2.jpg',
#  'main_data\\Bear\\Bear_27.jpeg',
#  'main_data\\Panda\\Panda_5.jpeg',
#  'main_data\\Bear\\grizzly-thinker.jpg',
#  'main_data\\Elephant\\Elephant_14_3.jpg',
#  'main_data\\Elephant\\Elephant_2.jpeg',
#  'main_data\\Elephant\\african-elephant-encounter-at-dawn.jpg',
#  'main_data\\Panda\\photo-1617910879258-2aff8026515d.jpg',
#  'main_data\\Tiger\\Tiger_21_2.jpg',
#  'main_data\\Elephant\\elephant-approaching-isolated-17478929.jpg',
#  'main_data\\Panda\\photo-1505496875-17a0c521864c.jpg',
#  'main_data\\Horse\\horse-arabs-stallion-ride-53114.jpg',
#  'main_data\\Horse\\Horse_30_2.jpg',
#  'main_data\\Elephant\\Elephant_6_3.jpg',
#  'main_data\\Bear\\alaskan-brown-bear-12046482.jpg',
#  'main_data\\Horse\\photo-1553284965-fa61e9ad4795.jpg',
#  'main_data\\Bear\\waving-grizzly-bear.jpg',
#  'main_data\\Horse\\Horse_21_2.jpg',
#  'main_data\\Tiger\\isolated-profile-of-a-tiger.jpg',
#  'main_data\\Panda\\giant-panda-walking-in-the-woods.jpg',
#  'main_data\\Panda\\Panda_18.jpeg',
#  'main_data\\Panda\\close-up-of-bear-on-tree.jpg',
#  'main_data\\Tiger\\sumatran-tiger-critically-endangered-species-around-left-wild-global-day-july-th-daseep-three-year-42810728.jpg',
#  'main_data\\Elephant\\asian-elephant.jpg',
#  'main_data\\Horse\\pexels-photo-635499.jpg',
#  'main_data\\Horse\\Tallest-Horses-Suffolk-Punch-768x401.jpg',
#  'main_data\\Tiger\\Tiger_2_1.jpg',
#  'main_data\\Panda\\a-giant-panda-walking-portrait.jpg',
#  'main_data\\Panda\\Panda_8_3.jpg',
#  'main_data\\Elephant\\Elephant_7_2.jpg',
#  'main_data\\Elephant\\african-elephant-and-the-ngorongoro-savanna-in-tanzania.jpg',
#  'main_data\\Bear\\Bear_10.jpg',
#  'main_data\\Horse\\Horses14.jpg',
#  'main_data\\Horse\\Best-Horses-Arabian-768x401.jpg',
#  'main_data\\Elephant\\african-elephant-20157049.jpg',
#  'main_data\\Horse\\Horses43.jpg',
#  'main_data\\Horse\\black-horse-runs-14200120.jpg',
#  'main_data\\Tiger\\tiger-white-background-isolated-73110104.jpg',
#  'main_data\\Horse\\white-male-horse-in-desert-landscape.jpg',
#  'main_data\\Tiger\\Tiger_19.jpeg',
#  'main_data\\Panda\\Panda_17.jpeg',
#  'main_data\\Horse\\Horse_10_2.jpg',
#  'main_data\\Tiger\\Tiger_27.jpeg',
#  'main_data\\Panda\\Panda_9_4.jpg',
#  'main_data\\Tiger\\Tiger_20_4.jpg',
#  'main_data\\Elephant\\Elephant_9_4.jpg',
#  'main_data\\Horse\\American-Cream-768x401.jpg',
#  'main_data\\Tiger\\premium_photo-1661904930364-fe26ae15bba2.jpg',
#  'main_data\\Horse\\Best-Horses-Friesian-768x401.jpg',
#  'main_data\\Panda\\Panda_8.jpg',
#  'main_data\\Elephant\\african-elephant-curious-about-strange-smell.jpg',
#  'main_data\\Horse\\Horse_29_4.jpg',
#  'main_data\\Panda\\panda-eating-bamboo-leaves-26512123.jpg',
#  'main_data\\Bear\\brown-bear-roaring-side-view.jpg',
#  'main_data\\Tiger\\Tiger_2_3.jpg',
#  'main_data\\Panda\\Panda_21_2.jpg',
#  'main_data\\Tiger\\Tigers31.jpg',
#  'main_data\\Tiger\\Tigers36.jpg',
#  'main_data\\Horse\\photo-1605138673093-e333752f46df.jpg',
#  'main_data\\Tiger\\Tigers28.jpg',
#  'main_data\\Horse\\Horse_12_4.jpg',
#  'main_data\\Elephant\\pexels-photo-1054666.jpg',
#  'main_data\\Tiger\\Tiger_28_3.jpg',
#  'main_data\\Horse\\shutterstock_1269162133-768x401.jpg',
#  'main_data\\Panda\\giant-panda-18-months-ailuropoda-melanoleuca-8193462.jpg',
#  'main_data\\Horse\\Horse_8_2.jpg',
#  'main_data\\Horse\\Horse_3_3.jpg',
#  'main_data\\Tiger\\Tigers62.jpg',
#  'main_data\\Tiger\\a-tiger-outdoors.jpg',
#  'main_data\\Tiger\\Tiger_2_4.jpg',
#  'main_data\\Panda\\cute-panda-eating-bambus.jpg',
#  'main_data\\Elephant\\Elephant_27_1.jpg',
#  'main_data\\Tiger\\Tiger_13_4.jpg',
#  'main_data\\Horse\\Horses57.jpg',
#  'main_data\\Elephant\\portrait-big-tusker-bull-elephant-24373505.jpg',
#  'main_data\\Panda\\Panda_4_3.jpg',
#  'main_data\\Horse\\Horse_2_4.jpg',
#  'main_data\\Horse\\Tallest-Horses-Shire-768x401.jpg',
#  'main_data\\Horse\\Horse_14.jpeg',
#  'main_data\\Panda\\panda-pretty-giant-88963516.jpg',
#  'main_data\\Elephant\\elephant-move-11614729.jpg',
#  'main_data\\Horse\\Horse_13_2.jpg',
#  'main_data\\Horse\\Percheron-768x401.jpg',
#  'main_data\\Tiger\\Tiger_27_2.jpg',
#  'main_data\\Panda\\Panda_30_1.jpg',
#  'main_data\\Panda\\giant-panda-sleeping-ocean-park-hong-kong-53707606.jpg',
#  'main_data\\Horse\\Horses61.jpg',
#  'main_data\\Elephant\\Elephant-in-grass-768x401.jpg',
#  'main_data\\Panda\\panda-with-tongue-out.jpg',
#  'main_data\\Panda\\giant-panda-6-months-ailuropoda-melanoleuca-7981182.jpg',
#  'main_data\\Bear\\Bear_17_3.jpg',
#  'main_data\\Elephant\\elephant-19517238.jpg',
#  'main_data\\Tiger\\Tiger_26_3.jpg',
#  'main_data\\Panda\\6-month-old-giant-panda-on-a-white-background.jpg',
#  'main_data\\Elephant\\wild-aggressive-asian-elephant-or-elephas-maximus-indicus-roadblock-walking-head-on-in-summer.jpg',
#  'main_data\\Horse\\Horse_2_2.jpg',
#  'main_data\\Horse\\mixed-breed-of-spanish-and-arabian-horse.jpg',
#  'main_data\\Elephant\\elephant-standing-on-white-lifting-one-leg.jpg',
#  'main_data\\Tiger\\Tiger_12_1.jpg',
#  'main_data\\Bear\\Bear_5_1.jpg',
#  'main_data\\Tiger\\Tiger_25_3.jpg',
#  'main_data\\Elephant\\elefant-isolated-on-white-with-clipping-path.jpg',
#  'main_data\\Elephant\\the-african-elephant-in-the-okavango-delta.jpg',
#  'main_data\\Elephant\\Elephant_12_2.jpg',
#  'main_data\\Horse\\photo-1553284966-19b8815c7817.jpg',
#  'main_data\\Bear\\Bear_16_3.jpg',
#  'main_data\\Tiger\\Tigers90.jpg',
#  'main_data\\Elephant\\Elephant_20_2.jpg',
#  'main_data\\Elephant\\african-elephant-bull-3549263.jpg',
#  'main_data\\Elephant\\elephant-standing-on-white-background.jpg',
#  'main_data\\Tiger\\Tiger_9_3.jpg',
#  'main_data\\Elephant\\Elephant_15.jpeg',
#  'main_data\\Elephant\\Elephant_1_2.jpg',
#  'main_data\\Horse\\Horse_20_4.jpg',
#  'main_data\\Tiger\\Tigers57.jpg',
#  'main_data\\Elephant\\photo-1614698561633-5eb087077543.jpg',
#  'main_data\\Tiger\\Tiger_28_4.jpg',
#  'main_data\\Panda\\Panda_15_3.jpg',
#  'main_data\\Tiger\\sumatran-tiger-roaring.jpg',
#  'main_data\\Elephant\\Elephant_29_4.jpg',
#  'main_data\\Tiger\\Tiger_27_1.jpg',
#  'main_data\\Panda\\Panda_24_2.jpg',
#  'main_data\\Panda\\panda-tree-19804770.jpg',
#  'main_data\\Horse\\Best-Horses-Shire-768x401.jpg',
#  'main_data\\Elephant\\elephant-3513006.jpg',
#  'main_data\\Panda\\Panda_25.jpeg',
#  'main_data\\Elephant\\Elephant-isolated-768x401.jpg',
#  'main_data\\Bear\\Bear_17.jpeg',
#  'main_data\\Horse\\Best-Horses-header-768x401.jpg',
#  'main_data\\Elephant\\Elephant-header-768x329.jpg',
#  'main_data\\Bear\\photo-1599948058230-78896e742f7e.jpg',
#  'main_data\\Tiger\\Tiger_20_3.jpg',
#  'main_data\\Tiger\\Tiger_14.jpeg',
#  'main_data\\Panda\\Panda_28_2.jpg',
#  'main_data\\Horse\\gray-stallion-galloping.jpg',
#  'main_data\\Tiger\\Tiger_20_1.jpg',
#  'main_data\\Horse\\Horses29.jpg',
#  'main_data\\Panda\\Panda_6_2.jpg',
#  'main_data\\Elephant\\elephant-walking-near-lake.jpg',
#  'main_data\\Bear\\bear_4_1.jpg',
#  'main_data\\Horse\\piebald-horse-run-in-flowers.jpg',
#  'main_data\\Tiger\\Tiger_25_1.jpg',
#  'main_data\\Panda\\Panda_10.jpeg',
#  'main_data\\Panda\\giant-panda-25855588.jpg',
#  'main_data\\Elephant\\elephant.jpg',
#  'main_data\\Panda\\photo-1526716173434-a1b560f2065d.jpg',
#  'main_data\\Elephant\\pexels-photo-1057366.jpg',
#  'main_data\\Elephant\\african-elephant-clipped.jpg',
#  'main_data\\Bear\\Bear_22_3.jpg',
#  'main_data\\Tiger\\bengal-tiger-in-the-forest-of-bannerghatta-in-karnataka-india.jpg',
#  'main_data\\Tiger\\tiger-939099.jpg',
#  'main_data\\Bear\\growling-grizzly-bear-26609811.jpg',
#  'main_data\\Horse\\Horses19.jpg',
#  'main_data\\Horse\\Horses66.jpg',
#  'main_data\\Panda\\giant-panda-resting.jpg',
#  'main_data\\Bear\\Bear_21_1.jpg',
#  'main_data\\Horse\\Horses11.jpg',
#  'main_data\\Bear\\growling-grizzly-bear.jpg',
#  'main_data\\Panda\\Panda_13.jpg',
#  'main_data\\Tiger\\Tiger_24_1.jpg',
#  'main_data\\Tiger\\tiger-predator-animal-tooth-47312.jpg',
#  'main_data\\Panda\\pa.jpeg',
#  'main_data\\Horse\\Horses30.jpg',
#  'main_data\\Horse\\Horse_12.jpeg',
#  'main_data\\Panda\\Panda_16_3.jpg',
#  'main_data\\Horse\\Horses18.jpg',
#  'main_data\\Horse\\Horse_15_2.jpg',
#  'main_data\\Panda\\Panda_26_3.jpg',
#  'main_data\\Bear\\photo-1576076819613-26f8537ae375.jpg',
#  'main_data\\Elephant\\Elephant_28_4.jpg',
#  'main_data\\Horse\\horse-standing-on-field.jpg',
#  'main_data\\Bear\\european-brown-bear-wild-animal-bear-dangerous-158140.jpg',
#  'main_data\\Panda\\Panda_4_2.jpg',
#  'main_data\\Elephant\\elephant-3832516_640.jpg',
#  'main_data\\Bear\\Bear_10_3.jpg',
#  'main_data\\Bear\\Bear_26_2.jpg',
#  'main_data\\Tiger\\crouching-tiger.jpg',
#  'main_data\\Tiger\\Tiger_17.jpeg',
#  'main_data\\Panda\\giant-panda-18-months-ailuropoda-melanoleuca-7980612.jpg',
#  'main_data\\Bear\\bear-838688_640.jpg',
#  'main_data\\Bear\\Bear_28_1.jpg',
#  'main_data\\Tiger\\Tigers43.jpg',
#  'main_data\\Horse\\Horse_25_2.jpg',
#  'main_data\\Horse\\Horse_29_2.jpg',
#  'main_data\\Tiger\\bengal-tiger-jumping.jpg',
#  'main_data\\Horse\\horse-outdoor-on-pasture.jpg',
#  'main_data\\Panda\\Panda_12.jpg',
#  'main_data\\Elephant\\Elephant_15_4.jpg',
#  'main_data\\Elephant\\elephant-large-tusks-26146562.jpg',
#  'main_data\\Panda\\Panda_19_1.jpg',
#  'main_data\\Elephant\\Elephant_17_2.jpg',
#  'main_data\\Horse\\Tallest-Horses-Percheron-768x401.jpg',
#  'main_data\\Elephant\\Elephant_6_1.jpg',
#  'main_data\\Elephant\\Elephant_30_1.jpg',
#  'main_data\\Bear\\pexels-photo-2546941.jpg',
#  'main_data\\Horse\\Horses20.jpg',
#  'main_data\\Panda\\Panda_26_4.jpg',
#  'main_data\\Bear\\bear_8.jpg',
#  'main_data\\Tiger\\Tigers50.jpg',
#  'main_data\\Tiger\\Tiger_4.jpg',
#  'main_data\\Bear\\grizzly-bear-16193093.jpg',
#  'main_data\\Bear\\bear_4_2.jpg',
#  'main_data\\Horse\\photo-1593179449458-e0d43d512551.jpg',
#  'main_data\\Elephant\\afrcan-elephant-on-the-move.jpg',
#  'main_data\\Horse\\Horses21.jpg',
#  'main_data\\Panda\\cute-panda-bear-climbing-in-tree.jpg',
#  'main_data\\Horse\\premium_photo-1669842069755-cfba5f2f677d.jpg',
#  'main_data\\Bear\\Bear_12.jpeg',
#  'main_data\\Tiger\\tiger-3264048_640.jpg',
#  'main_data\\Horse\\pexels-photo-634613.jpg',
#  'main_data\\Panda\\chengdu-panda.jpg',
#  'main_data\\Horse\\bay-horse-portrait.jpg',
#  'main_data\\Elephant\\african-elephant-4007331.jpg',
#  'main_data\\Panda\\Panda_16_1.jpg',
#  'main_data\\Horse\\Horse_9_3.jpg',
#  'main_data\\Panda\\giant-panda-19388.jpg',
#  'main_data\\Horse\\Horse_14_2.jpg',
#  'main_data\\Tiger\\Tiger-in-the-Forest-768x401.jpg',
#  'main_data\\Elephant\\Elephant_7.jpg',
#  'main_data\\Elephant\\pexels-photo-3739327.jpg',
#  'main_data\\Elephant\\Elephant_24.jpeg',
#  'main_data\\Tiger\\Deadliest-Cats-Tiger-768x401.jpg',
#  'main_data\\Elephant\\elephant-standing-on-hind-legs-performing-trick.jpg',
#  'main_data\\Tiger\\pexels-photo-3777200.jpg',
#  'main_data\\Panda\\panda-on-white-background.jpg',
#  'main_data\\Horse\\Horse_29_3.jpg',
#  'main_data\\Tiger\\Tiger_1_3.jpg',
#  'main_data\\Horse\\Horse_8_1.jpg',
#  'main_data\\Bear\\Bear_6_1.jpg',
#  'main_data\\Bear\\bear_1_3.jpg',
#  'main_data\\Horse\\Horses32.jpg',
#  'main_data\\Horse\\h.jpeg',
#  'main_data\\Tiger\\photo-1551972251-12070d63502a.jpg',
#  'main_data\\Bear\\Bear_12_1.jpg',
#  'main_data\\Bear\\Bear_6.jpg',
#  'main_data\\Panda\\Panda_29.jpeg',
#  'main_data\\Panda\\panda.jpg',
#  'main_data\\Tiger\\Tiger_7_1.jpg',
#  'main_data\\Elephant\\african-elephant-1415617.jpg',
#  'main_data\\Horse\\pexels-photo-1996333.jpg',
#  'main_data\\Horse\\sorrel-quarter-horse-gelding-eating-grass-in-meadow-autumn-close-up.jpg',
#  'main_data\\Bear\\european-brown-bear-wild-animal-bear-dangerous-158233.jpg',
#  'main_data\\Elephant\\side-view-african-elephant-bull-trunk-up-loxodonta-africana-40158313.jpg',
#  'main_data\\Tiger\\Tiger_18_1.jpg',
#  'main_data\\Elephant\\Elephant_22_4.jpg',
#  'main_data\\Tiger\\Tiger_12.jpg',
#  'main_data\\Panda\\Panda_19.jpg',
#  'main_data\\Horse\\running-horse-desert-18709594.jpg',
#  'main_data\\Tiger\\tiger-6606260.jpg',
#  'main_data\\Elephant\\Elephant_28_3.jpg',
#  'main_data\\Tiger\\panthera-tigris-altaica-tiger-siberian-amurtiger-162173.jpg',
#  'main_data\\Horse\\Horse_4_2.jpg',
#  'main_data\\Horse\\Horses35.jpg',
#  'main_data\\Horse\\Horses68.jpg',
#  'main_data\\Horse\\photo-1553284965-83fd3e82fa5a.jpg',
#  'main_data\\Tiger\\siberian-tiger-isolated.jpg',
#  'main_data\\Bear\\Grizzly-Bear-e1652377327826-768x401.jpg',
#  'main_data\\Horse\\golden-horse-3887574.jpg',
#  'main_data\\Bear\\Bear_22_1.jpg',
#  'main_data\\Horse\\Most-Expensive-Horses-Friesian-768x401.jpg',
#  'main_data\\Tiger\\sumatran-tiger.jpg',
#  'main_data\\Elephant\\Elephant_24_2.jpg',
#  'main_data\\Horse\\Horses5.jpg',
#  'main_data\\Panda\\panda-resting-in-a-tree.jpg',
#  'main_data\\Bear\\brown-bear-katmai-national-park-alaska.jpg',
#  'main_data\\Horse\\Arabian-Horse-768x401.jpg',
#  'main_data\\Elephant\\Elephant_22.jpeg',
#  'main_data\\Tiger\\Tiger_23_2.jpg',
#  'main_data\\Horse\\white-horse-portrait-blossom-white-horse-portrait-spring-pink-blossom-tree-119321623.jpg',
#  'main_data\\Bear\\Bear_3_3.jpg',
#  'main_data\\Horse\\Most-Expensive-Horses-Thoroughbred-768x401.jpg',
#  'main_data\\Bear\\Bear_5.jpeg',
#  'main_data\\Elephant\\Elephant_11.jpeg',
#  'main_data\\Panda\\giant-panda-bear-17226921.jpg',
#  'main_data\\Bear\\GettyImages-1358392546.jpg',
#  'main_data\\Horse\\Horse_2_1.jpg',
#  'main_data\\Tiger\\Tiger_11_3.jpg',
#  'main_data\\Tiger\\Tigers47.jpg',
#  'main_data\\Horse\\Horse_6_2.jpg',
#  'main_data\\Panda\\giant-panda-bear-tree-16333299.jpg',
#  'main_data\\Tiger\\Tiger-header-768x329.jpg',
#  'main_data\\Tiger\\a-large-tiger-in-bandhavgarh-national-park-madhya-pradesh-india.jpg',
#  'main_data\\Horse\\Horse_22_2.jpg',
#  'main_data\\Horse\\Horses7.jpg',
#  'main_data\\Tiger\\Tiger_22_3.jpg',
#  'main_data\\Bear\\Bear_29_3.jpg',
#  'main_data\\Elephant\\african-elephant-isolated-white-8115112.jpg',
#  'main_data\\Tiger\\Tigers67.jpg',
#  'main_data\\Bear\\Bear_3.jpg',
#  'main_data\\Horse\\Horse_9_2.jpg',
#  'main_data\\Panda\\Panda_24_3.jpg',
#  'main_data\\Horse\\Horses6.jpg',
#  'main_data\\Bear\\Bear_2_1.jpg',
#  'main_data\\Elephant\\Elephant_19.jpeg',
#  'main_data\\Elephant\\Fat-Animal_-African-Elephant-768x401.jpg',
#  'main_data\\Tiger\\Tiger_26_4.jpg',
#  'main_data\\Bear\\pexels-photo-1499104.jpg',
#  'main_data\\Horse\\Horse_25.jpeg',
#  'main_data\\Tiger\\tiger-4349885.jpg',
#  'main_data\\Horse\\photo-1566251037378-5e04e3bec343.jpg',
#  'main_data\\Tiger\\strong-male-siberian-tiger-or-amur-tiger.jpg',
#  'main_data\\Tiger\\Tigers40.jpg',
#  'main_data\\Panda\\Panda_22_2.jpg',
#  'main_data\\Panda\\Panda_14_2.jpg',
#  'main_data\\Tiger\\Tigers33.jpg',
#  'main_data\\Tiger\\pexels-photo-247615.jpg',
#  'main_data\\Horse\\Horse_18_2.jpg',
#  'main_data\\Panda\\Panda_7_2.jpg',
#  'main_data\\Panda\\Panda_7_1.jpg',
#  'main_data\\Tiger\\Tiger_4_2.jpg',
#  'main_data\\Elephant\\Elephant_29_2.jpg',
#  'main_data\\Elephant\\rear-view-of-african-elephant-walking-on-field-against-sky.jpg',
#  'main_data\\Bear\\Bear_10_2.jpg',
#  'main_data\\Elephant\\photo-1581852017103-68ac65514cf7.jpg',
#  'main_data\\Bear\\premium_photo-1661963987217-00df8f4ebad3.jpg',
#  'main_data\\Bear\\Bear_2_2.jpg',
#  'main_data\\Tiger\\Tigers107.jpg',
#  'main_data\\Elephant\\wild-elephant-walking-in-street-looking-for-the-water-in-khao-yai-national-park-thailand.jpg',
#  'main_data\\Panda\\giant-panda-sad-tired-bored-looking-pose-chengdu-china-resting-49798376.jpg',
#  'main_data\\Elephant\\Elephant_18_1.jpg',
#  'main_data\\Horse\\Horse_23_2.jpg',
#  'main_data\\Tiger\\Tiger_3_3.jpg',
#  'main_data\\Horse\\Best-Horses-Belgian-Draft-Horse-768x401.jpg',
#  'main_data\\Bear\\premium_photo-1664300680098-76d8f082cb60.jpg',
#  'main_data\\Elephant\\Elephant_22_2.jpg',
#  'main_data\\Panda\\giant-panda-ailuropoda-melanoleuca.jpg',
#  'main_data\\Panda\\Panda_29_2.jpg',
#  'main_data\\Tiger\\Tiger_11_1.jpg',
#  'main_data\\Bear\\bear-isolated.jpg',
#  'main_data\\Tiger\\Tiger_21_1.jpg',
#  'main_data\\Bear\\Bear_13_3.jpg',
#  'main_data\\Panda\\giant-panda-28543366.jpg',
#  'main_data\\Horse\\Horse_9.jpg',
#  'main_data\\Horse\\pexels-photo-461717.jpg',
#  'main_data\\Tiger\\tigress-in-mist.jpg',
#  ...]

# %%
labels
# Out:
# [0,
#  4,
#  4,
#  2,
#  2,
#  0,
#  2,
#  4,
#  1,
#  4,
#  4,
#  1,
#  3,
#  4,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  4,
#  2,
#  3,
#  4,
#  3,
#  1,
#  4,
#  3,
#  1,
#  0,
#  3,
#  3,
#  3,
#  1,
#  4,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  0,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  2,
#  1,
#  2,
#  1,
#  4,
#  3,
#  1,
#  1,
#  4,
#  4,
#  0,
#  3,
#  2,
#  3,
#  2,
#  3,
#  0,
#  0,
#  0,
#  1,
#  4,
#  2,
#  3,
#  4,
#  1,
#  1,
#  4,
#  2,
#  0,
#  1,
#  2,
#  4,
#  4,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  0,
#  3,
#  1,
#  0,
#  3,
#  0,
#  0,
#  3,
#  3,
#  2,
#  2,
#  0,
#  3,
#  2,
#  3,
#  1,
#  4,
#  1,
#  0,
#  4,
#  2,
#  2,
#  2,
#  4,
#  3,
#  2,
#  3,
#  1,
#  2,
#  3,
#  0,
#  1,
#  3,
#  1,
#  3,
#  4,
#  1,
#  2,
#  4,
#  2,
#  4,
#  4,
#  3,
#  1,
#  4,
#  2,
#  1,
#  1,
#  3,
#  3,
#  0,
#  2,
#  2,
#  0,
#  0,
#  1,
#  4,
#  1,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  4,
#  1,
#  4,
#  0,
#  2,
#  4,
#  1,
#  3,
#  1,
#  2,
#  4,
#  2,
#  3,
#  1,
#  1,
#  4,
#  4,
#  0,
#  3,
#  2,
#  3,
#  4,
#  3,
#  1,
#  4,
#  0,
#  3,
#  4,
#  0,
#  2,
#  0,
#  3,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  0,
#  3,
#  4,
#  3,
#  2,
#  1,
#  0,
#  1,
#  3,
#  3,
#  2,
#  4,
#  3,
#  2,
#  0,
#  0,
#  4,
#  3,
#  1,
#  4,
#  2,
#  2,
#  3,
#  4,
#  2,
#  0,
#  2,
#  4,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  3,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  3,
#  0,
#  2,
#  0,
#  1,
#  4,
#  1,
#  4,
#  2,
#  3,
#  2,
#  1,
#  1,
#  4,
#  1,
#  2,
#  0,
#  4,
#  1,
#  2,
#  4,
#  3,
#  1,
#  1,
#  3,
#  1,
#  0,
#  4,
#  1,
#  1,
#  2,
#  3,
#  2,
#  0,
#  0,
#  4,
#  1,
#  0,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  0,
#  3,
#  0,
#  3,
#  3,
#  1,
#  0,
#  3,
#  0,
#  1,
#  1,
#  1,
#  3,
#  3,
#  2,
#  0,
#  1,
#  4,
#  4,
#  0,
#  4,
#  3,
#  2,
#  4,
#  0,
#  0,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  4,
#  2,
#  2,
#  0,
#  3,
#  3,
#  1,
#  1,
#  3,
#  4,
#  3,
#  3,
#  0,
#  3,
#  0,
#  2,
#  3,
#  1,
#  1,
#  0,
#  1,
#  1,
#  0,
#  4,
#  2,
#  3,
#  4,
#  1,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  2,
#  0,
#  1,
#  3,
#  4,
#  0,
#  4,
#  3,
#  2,
#  0,
#  2,
#  0,
#  1,
#  0,
#  3,
#  0,
#  4,
#  0,
#  2,
#  3,
#  1,
#  1,
#  2,
#  4,
#  3,
#  1,
#  3,
#  4,
#  1,
#  1,
#  2,
#  3,
#  0,
#  1,
#  4,
#  4,
#  0,
#  2,
#  3,
#  1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  4,
#  1,
#  3,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  4,
#  1,
#  1,
#  0,
#  2,
#  2,
#  3,
#  3,
#  4,
#  1,
#  1,
#  4,
#  1,
#  3,
#  2,
#  3,
#  3,
#  4,
#  3,
#  1,
#  2,
#  4,
#  0,
#  1,
#  2,
#  3,
#  4,
#  3,
#  2,
#  4,
#  2,
#  0,
#  4,
#  3,
#  0,
#  2,
#  4,
#  3,
#  3,
#  2,
#  4,
#  0,
#  3,
#  1,
#  3,
#  3,
#  1,
#  4,
#  2,
#  4,
#  4,
#  4,
#  0,
#  3,
#  0,
#  3,
#  4,
#  4,
#  4,
#  1,
#  3,
#  2,
#  1,
#  4,
#  1,
#  1,
#  2,
#  3,
#  3,
#  4,
#  4,
#  4,
#  1,
#  0,
#  4,
#  0,
#  4,
#  1,
#  4,
#  2,
#  1,
#  1,
#  1,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  0,
#  4,
#  2,
#  2,
#  1,
#  1,
#  0,
#  1,
#  1,
#  2,
#  4,
#  0,
#  3,
#  0,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  0,
#  4,
#  4,
#  0,
#  4,
#  0,
#  1,
#  4,
#  3,
#  1,
#  0,
#  3,
#  0,
#  4,
#  2,
#  2,
#  3,
#  2,
#  0,
#  0,
#  3,
#  4,
#  3,
#  0,
#  0,
#  4,
#  3,
#  1,
#  2,
#  1,
#  3,
#  1,
#  3,
#  4,
#  1,
#  1,
#  4,
#  1,
#  2,
#  4,
#  2,
#  4,
#  4,
#  0,
#  3,
#  1,
#  0,
#  4,
#  3,
#  2,
#  0,
#  2,
#  1,
#  3,
#  0,
#  4,
#  4,
#  1,
#  4,
#  2,
#  1,
#  2,
#  3,
#  3,
#  4,
#  1,
#  1,
#  4,
#  4,
#  4,
#  2,
#  0,
#  1,
#  3,
#  1,
#  0,
#  2,
#  2,
#  4,
#  3,
#  2,
#  3,
#  4,
#  1,
#  0,
#  1,
#  1,
#  0,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  2,
#  4,
#  0,
#  2,
#  1,
#  3,
#  2,
#  2,
#  4,
#  1,
#  1,
#  4,
#  4,
#  0,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  1,
#  3,
#  2,
#  4,
#  2,
#  0,
#  2,
#  4,
#  3,
#  4,
#  4,
#  2,
#  2,
#  1,
#  4,
#  4,
#  3,
#  0,
#  3,
#  1,
#  3,
#  2,
#  4,
#  1,
#  2,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  4,
#  0,
#  3,
#  0,
#  1,
#  1,
#  1,
#  3,
#  4,
#  1,
#  3,
#  2,
#  2,
#  1,
#  0,
#  2,
#  0,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  1,
#  2,
#  2,
#  4,
#  3,
#  3,
#  1,
#  1,
#  0,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  4,
#  3,
#  2,
#  4,
#  3,
#  4,
#  1,
#  2,
#  4,
#  2,
#  3,
#  1,
#  2,
#  3,
#  0,
#  4,
#  3,
#  4,
#  4,
#  2,
#  4,
#  2,
#  1,
#  4,
#  2,
#  3,
#  2,
#  2,
#  4,
#  4,
#  4,
#  3,
#  1,
#  4,
#  2,
#  1,
#  3,
#  2,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  4,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  0,
#  1,
#  4,
#  3,
#  1,
#  2,
#  2,
#  1,
#  4,
#  0,
#  4,
#  1,
#  1,
#  1,
#  2,
#  0,
#  4,
#  1,
#  1,
#  1,
#  4,
#  1,
#  1,
#  2,
#  4,
#  1,
#  4,
#  3,
#  4,
#  1,
#  4,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  0,
#  2,
#  1,
#  0,
#  4,
#  4,
#  3,
#  2,
#  4,
#  2,
#  3,
#  1,
#  0,
#  2,
#  4,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  0,
#  4,
#  4,
#  0,
#  2,
#  2,
#  3,
#  0,
#  2,
#  0,
#  3,
#  4,
#  4,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  0,
#  1,
#  2,
#  0,
#  3,
#  1,
#  0,
#  0,
#  4,
#  4,
#  3,
#  0,
#  0,
#  4,
#  2,
#  2,
#  4,
#  2,
#  3,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  0,
#  2,
#  3,
#  0,
#  4,
#  4,
#  0,
#  0,
#  2,
#  1,
#  2,
#  3,
#  2,
#  0,
#  4,
#  2,
#  3,
#  2,
#  1,
#  3,
#  2,
#  3,
#  2,
#  4,
#  1,
#  1,
#  1,
#  4,
#  1,
#  4,
#  3,
#  2,
#  4,
#  2,
#  0,
#  0,
#  2,
#  2,
#  4,
#  0,
#  0,
#  3,
#  3,
#  4,
#  1,
#  2,
#  2,
#  0,
#  1,
#  4,
#  1,
#  4,
#  3,
#  2,
#  4,
#  1,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  0,
#  2,
#  0,
#  2,
#  4,
#  1,
#  2,
#  3,
#  0,
#  2,
#  1,
#  4,
#  2,
#  0,
#  2,
#  0,
#  1,
#  3,
#  0,
#  2,
#  4,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  2,
#  4,
#  0,
#  1,
#  4,
#  0,
#  2,
#  3,
#  2,
#  0,
#  1,
#  1,
#  4,
#  0,
#  2,
#  4,
#  2,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  2,
#  3,
#  3,
#  4,
#  1,
#  1,
#  0,
#  1,
#  0,
#  0,
#  4,
#  1,
#  3,
#  1,
#  2,
#  4,
#  2,
#  0,
#  1,
#  3,
#  3,
#  4,
#  0,
#  4,
#  0,
#  3,
#  2,
#  2,
#  4,
#  ...]

# %%
data[0]
# Out:
# array([[[198., 202., 197.],
#         [208., 212., 207.],
#         [212., 219., 214.],
#         ...,
#         [142., 152., 146.],
#         [187., 196., 191.],
#         [164., 170., 165.]],
#
#        [[194., 198., 193.],
#         [185., 189., 184.],
#         [172., 179., 174.],
#         ...,
#         [206., 212., 207.],
#         [202., 207., 202.],
#         [223., 226., 221.]],
#
#        [[211., 217., 212.],
#         [222., 227., 222.],
#         [205., 212., 207.],
#         ...,
#         [233., 236., 231.],
#         [232., 236., 232.],
#         [206., 207., 203.]],
#
#        ...,
#
#        [[134., 143., 147.],
#         [ 99., 114., 120.],
#         [138., 153., 159.],
#         ...,
#         [144., 153., 157.],
#         [ 70.,  82.,  86.],
#         [133., 144., 151.]],
#
#        [[144., 149., 155.],
#         [145., 155., 162.],
#         [137., 148., 155.],
#         ...,
#         [ 95., 113., 116.],
#         [ 94., 115., 117.],
#         [103., 123., 128.]],
#
#        [[120., 131., 138.],
#         [102., 112., 118.],
#         [103., 115., 122.],
#         ...,
#         [ 94., 115., 120.],
#         [102., 122., 127.],
#         [ 86., 103., 106.]]], dtype=float32)

# %%
data[0].shape
# Out:
# (28, 28, 3)

# %%
type(data)
# Out:
# list

# %%
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
data[0]
# Out:
# array([[[0.77647059, 0.79215686, 0.77254902],
#         [0.81568627, 0.83137255, 0.81176471],
#         [0.83137255, 0.85882353, 0.83921569],
#         ...,
#         [0.55686275, 0.59607843, 0.57254902],
#         [0.73333333, 0.76862745, 0.74901961],
#         [0.64313725, 0.66666667, 0.64705882]],
#
#        [[0.76078431, 0.77647059, 0.75686275],
#         [0.7254902 , 0.74117647, 0.72156863],
#         [0.6745098 , 0.70196078, 0.68235294],
#         ...,
#         [0.80784314, 0.83137255, 0.81176471],
#         [0.79215686, 0.81176471, 0.79215686],
#         [0.8745098 , 0.88627451, 0.86666667]],
#
#        [[0.82745098, 0.85098039, 0.83137255],
#         [0.87058824, 0.89019608, 0.87058824],
#         [0.80392157, 0.83137255, 0.81176471],
#         ...,
#         [0.91372549, 0.9254902 , 0.90588235],
#         [0.90980392, 0.9254902 , 0.90980392],
#         [0.80784314, 0.81176471, 0.79607843]],
#
#        ...,
#
#        [[0.5254902 , 0.56078431, 0.57647059],
#         [0.38823529, 0.44705882, 0.47058824],
#         [0.54117647, 0.6       , 0.62352941],
#         ...,
#         [0.56470588, 0.6       , 0.61568627],
#         [0.2745098 , 0.32156863, 0.3372549 ],
#         [0.52156863, 0.56470588, 0.59215686]],
#
#        [[0.56470588, 0.58431373, 0.60784314],
#         [0.56862745, 0.60784314, 0.63529412],
#         [0.5372549 , 0.58039216, 0.60784314],
#         ...,
#         [0.37254902, 0.44313725, 0.45490196],
#         [0.36862745, 0.45098039, 0.45882353],
#         [0.40392157, 0.48235294, 0.50196078]],
#
#        [[0.47058824, 0.51372549, 0.54117647],
#         [0.4       , 0.43921569, 0.4627451 ],
#         [0.40392157, 0.45098039, 0.47843137],
#         ...,
#         [0.36862745, 0.45098039, 0.47058824],
#         [0.4       , 0.47843137, 0.49803922],
#         [0.3372549 , 0.40392157, 0.41568627]]])

# %%
pd.Series(labels).value_counts()
# Out:
# 4    291
# 2    283
# 3    241
# 1    238
# 0    174
# Name: count, dtype: int64

# %%
(trainx, testx, trainy, testy) = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
trainy
# Out:
# array([2, 0, 3, 4, 4, 4, 4, 0, 4, 3, 1, 4, 4, 0, 4, 1, 4, 0, 2, 4, 2, 4,
#        4, 4, 4, 0, 2, 4, 4, 4, 1, 0, 2, 1, 3, 0, 4, 3, 3, 3, 2, 4, 0, 3,
#        0, 3, 1, 3, 3, 2, 3, 4, 3, 1, 3, 3, 4, 1, 3, 0, 4, 1, 2, 4, 2, 3,
#        2, 2, 2, 0, 2, 3, 2, 4, 3, 4, 1, 1, 3, 4, 0, 4, 0, 0, 2, 3, 3, 4,
#        2, 0, 1, 1, 2, 0, 1, 0, 2, 2, 3, 0, 3, 3, 1, 2, 0, 4, 2, 2, 3, 4,
#        3, 4, 3, 4, 3, 1, 4, 0, 2, 2, 4, 2, 4, 2, 3, 2, 1, 3, 2, 4, 1, 4,
#        1, 0, 1, 2, 2, 1, 1, 2, 2, 0, 0, 0, 3, 2, 1, 1, 3, 2, 1, 3, 1, 1,
#        0, 3, 2, 4, 4, 4, 2, 4, 3, 0, 0, 1, 3, 4, 1, 1, 4, 2, 2, 4, 3, 0,
#        4, 2, 2, 3, 3, 4, 0, 3, 1, 3, 3, 2, 3, 4, 2, 0, 4, 0, 2, 1, 1, 1,
#        4, 1, 0, 4, 4, 4, 2, 0, 2, 1, 4, 2, 3, 4, 0, 4, 2, 4, 2, 3, 1, 0,
#        1, 2, 0, 4, 3, 3, 1, 0, 4, 2, 2, 4, 1, 4, 1, 1, 3, 4, 0, 0, 4, 1,
#        3, 4, 1, 3, 0, 3, 3, 4, 1, 2, 4, 4, 4, 1, 3, 0, 2, 1, 3, 4, 4, 2,
#        4, 0, 1, 3, 1, 2, 3, 4, 1, 0, 1, 0, 4, 4, 3, 3, 3, 2, 1, 4, 3, 2,
#        4, 4, 2, 1, 1, 1, 4, 2, 1, 2, 2, 1, 0, 2, 3, 4, 2, 0, 2, 3, 1, 0,
#        2, 3, 4, 0, 4, 4, 3, 2, 1, 0, 2, 0, 4, 2, 0, 4, 4, 2, 1, 1, 4, 3,
#        1, 3, 3, 4, 2, 1, 1, 3, 4, 2, 4, 0, 3, 2, 2, 3, 4, 3, 4, 2, 2, 2,
#        2, 1, 0, 3, 2, 3, 2, 4, 3, 1, 0, 1, 2, 2, 0, 0, 4, 1, 3, 0, 0, 2,
#        3, 3, 1, 0, 2, 2, 3, 1, 3, 1, 0, 4, 1, 4, 3, 1, 1, 1, 4, 2, 0, 4,
#        0, 3, 3, 2, 4, 2, 1, 2, 3, 1, 2, 4, 4, 2, 0, 4, 1, 4, 0, 3, 4, 1,
#        1, 1, 4, 3, 1, 0, 3, 0, 4, 4, 0, 3, 4, 4, 1, 2, 4, 1, 1, 4, 1, 1,
#        3, 1, 2, 4, 2, 2, 4, 2, 2, 1, 0, 4, 2, 2, 2, 4, 1, 3, 2, 0, 2, 3,
#        1, 1, 1, 1, 2, 2, 1, 3, 1, 3, 1, 2, 3, 4, 4, 0, 4, 0, 4, 1, 3, 0,
#        4, 1, 2, 1, 2, 3, 2, 1, 2, 1, 1, 2, 1, 4, 4, 4, 4, 3, 2, 0, 2, 1,
#        2, 0, 2, 4, 2, 4, 2, 0, 3, 4, 3, 0, 2, 2, 1, 4, 3, 3, 4, 4, 2, 3,
#        1, 4, 2, 4, 4, 2, 2, 1, 1, 1, 2, 0, 4, 1, 0, 0, 4, 0, 0, 1, 4, 0,
#        3, 4, 2, 1, 1, 3, 2, 4, 3, 2, 2, 4, 4, 3, 4, 3, 2, 3, 3, 4, 4, 2,
#        0, 4, 3, 2, 1, 3, 3, 3, 1, 3, 1, 4, 0, 4, 3, 3, 0, 1, 2, 3, 0, 3,
#        4, 1, 2, 0, 2, 3, 2, 2, 1, 4, 2, 3, 3, 3, 2, 4, 4, 3, 3, 2, 4, 1,
#        0, 0, 2, 2, 4, 0, 1, 2, 0, 4, 3, 2, 1, 1, 4, 4, 4, 3, 2, 3, 3, 4,
#        1, 2, 1, 2, 2, 0, 2, 3, 4, 2, 4, 1, 4, 3, 1, 4, 1, 2, 1, 3, 2, 3,
#        1, 3, 4, 4, 3, 4, 1, 2, 4, 4, 0, 2, 1, 1, 2, 4, 3, 2, 3, 3, 0, 1,
#        2, 4, 2, 4, 3, 3, 3, 4, 2, 1, 2, 0, 3, 2, 4, 4, 3, 0, 3, 0, 3, 4,
#        2, 2, 2, 3, 1, 3, 2, 0, 4, 0, 2, 3, 3, 0, 4, 4, 2, 2, 1, 1, 3, 4,
#        1, 2, 4, 0, 1, 4, 1, 0, 2, 4, 2, 4, 4, 2, 4, 1, 0, 4, 4, 2, 3, 2,
#        2, 1, 1, 2, 3, 2, 1, 2, 4, 0, 4, 0, 1, 2, 2, 4, 3, 3, 3, 3, 4, 3,
#        1, 1, 2, 2, 3, 2, 1, 2, 3, 3, 0, 1, 0, 3, 4, 2, 1, 3, 4, 1, 2, 4,
#        1, 4, 1, 2, 3, 4, 3, 3, 1, 4, 1, 2, 2, 2, 4, 3, 0, 4, 2, 2, 4, 4,
#        1, 2, 1, 4, 1, 1, 3, 2, 1, 1, 2, 3, 2, 4, 4, 2, 2, 1, 0, 3, 2, 1,
#        2, 4, 4, 3, 0, 2, 4, 4, 0, 2, 1, 4, 0, 1, 4, 2, 3, 4, 2, 4, 3, 0,
#        0, 2, 4, 4, 2, 1, 3, 1, 3, 2, 1, 4, 4, 3, 3, 4, 2, 4, 3, 0, 3, 2,
#        1, 2, 0, 4, 3, 1, 0, 2, 1, 4, 3, 3, 1, 2, 1, 4, 1, 0, 2, 4, 3, 2,
#        1, 3, 4, 3, 1, 4, 3, 1, 4, 1, 2, 4, 4, 1, 0, 4, 4, 3, 3, 4, 3, 1,
#        4, 0, 3, 0, 3, 4, 1, 4, 0, 4, 3, 1, 0, 4, 1, 2, 1, 4, 0, 1, 2, 3,
#        2, 4, 1, 3, 0, 0, 1, 1, 4, 2, 2, 2, 2, 1, 3, 4, 4, 1, 3, 3, 2, 1,
#        2, 2, 2, 1, 4, 0, 4, 0, 2, 2, 3, 2, 1])

# %%
trainx.shape
# Out:
# (981, 28, 28, 3)

# %%
trainy.shape
# Out:
# (981,)

# %%
testx.shape
# Out:
# (246, 28, 28, 3)

# %%
testy.shape
# Out:
# (246,)

# %%
# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=30, 
                         width_shift_range=0.1, 
                         height_shift_range=0.1, 
                         shear_range=0.2, 
                         zoom_range=0.2, 
                         horizontal_flip=True, 
                         fill_mode="nearest")

# %%
def build_model(hp, num_classes, input_shape):
    model = Sequential()

    
    model.add(Conv2D(hp.Int('filters_1', min_value=32, max_value=256, step=32),
                     (hp.Choice('kernel_size_1', values=[2, 3])),
                     activation='relu', padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    
    model.add(Conv2D(hp.Int('filters_2', min_value=32, max_value=256, step=32),
                     (hp.Choice('kernel_size_2', values=[2, 3])),
                     activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    

    model.add(Conv2D(hp.Int('filters_3', min_value=64, max_value=512, step=64),
                     (hp.Choice('kernel_size_3', values=[2, 3])),
                     activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(hp.Int('filters_4', min_value=64, max_value=512, step=64),
                     (hp.Choice('kernel_size_4', values=[2, 3])),
                     activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    

    model.add(Conv2D(hp.Int('filters_5', min_value=128, max_value=1024, step=128),
                     (hp.Choice('kernel_size_5', values=[3, 4])),
                     activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(hp.Int('filters_6', min_value=128, max_value=1024, step=128),
                     (hp.Choice('kernel_size_6', values=[3, 4])),
                     activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    
    
    model.add(Conv2D(hp.Int('filters_7', min_value=256, max_value=2048, step=256),
                     (hp.Choice('kernel_size_7', values=[3, 4])),
                     activation='relu', padding='same',
                     kernel_regularizer=l2(hp.Float('l2_reg_7', min_value=0.001, max_value=0.1, sampling='LOG'))))
    model.add(BatchNormalization())
    
    model.add(Conv2D(hp.Int('filters_8', min_value=256, max_value=2048, step=256),
                     (hp.Choice('kernel_size_8', values=[3, 4])),
                     activation='relu', padding='same',
                     kernel_regularizer=l2(hp.Float('l2_reg_8', min_value=0.001, max_value=0.1, sampling='LOG'))))
    model.add(BatchNormalization())

# In a logarithmic scale, increments between values grow exponentially. For example, sampling might choose values 
# like 0.001, 0.003, 0.01, 0.03, 0.1, etc., rather than uniformly spaced values like 0.001, 0.02, 0.04, 0.06, 0.08, 0.1.
    
    
    model.add(Conv2D(hp.Int('filters_9', min_value=512, max_value=4096, step=512),
                     (hp.Choice('kernel_size_9', values=[3, 4])),
                     activation='relu', padding='same',
                     kernel_regularizer=l2(hp.Float('l2_reg_9', min_value=0.001, max_value=0.1, sampling='LOG'))))
    model.add(BatchNormalization())

    model.add(Conv2D(hp.Int('filters_10', min_value=512, max_value=4096, step=512),
                     (hp.Choice('kernel_size_10', values=[3, 4])),
                     activation='relu', padding='same',
                     kernel_regularizer=l2(hp.Float('l2_reg_10', min_value=0.001, max_value=0.01, sampling='LOG'))))
    model.add(BatchNormalization())

    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
    
    
    model.add(Flatten())
    
    model.add(Dense(hp.Int('units_1', min_value=128, max_value=2048, step=128), activation='relu'))
    model.add(Dense(hp.Int('units_2', min_value=512, max_value=4096, step=128), activation='relu'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1)))

    model.add(Dense(hp.Int('units_3', min_value=128, max_value=2048, step=128), activation='relu'))
    model.add(Dropout(hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))
    
    model.add(Dense(num_classes, activation='softmax'))

    hp_learning_rate = hp.Choice('learning_rate', values=[0.1, 0.001])

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

num_classes = 5 # Example number of classes
input_shape = (28, 28, 3)  # Example input shape

tuner = kt.RandomSearch(lambda hp: build_model(hp, num_classes, input_shape),
                        objective='val_accuracy',
                        max_trials=10,
                        directory='my_dir',
                        project_name='accuracy_loss')

early_stopping_loss = EarlyStopping(
    monitor='val_loss', 
    patience=4,  # Number of epochs to wait before stopping
    restore_best_weights=True,
    mode='min')

early_stopping_accuracy = EarlyStopping(
    monitor='val_accuracy', 
    patience=4,  # Number of epochs to wait before stopping
    restore_best_weights=True,
    mode='max')

# Assuming trainx, trainy, testx, testy are already defined
tuner.search(trainx, trainy, epochs=20, validation_data=(testx, testy), callbacks=[early_stopping_loss,early_stopping_accuracy ])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

model = build_model(best_hps, num_classes, input_shape)
print("[Info] Model Ready")
# Out:
# Reloading Tuner from my_dir\accuracy_loss\tuner0.json
# [Info] Model Ready

# %%
# Retrieve the best trial from the tuner
best_trial = tuner.oracle.get_best_trials(1)[0]

# Extract the trial ID
trial_id = best_trial.trial_id

# Extract the hyperparameters from the best trial
best_hyperparameters = best_trial.hyperparameters.values

# Print the trial ID
print("")
print(f"Trial no. : {trial_id}")
print("")

# Print the best hyperparameters
print("Best hyperparameters:")
for param, value in best_hyperparameters.items():
    print(f"{param}: {value}")
print("")

# Retrieve and print the best validation accuracy
best_accuracy = best_trial.metrics.get_best_value("val_accuracy")
print(f"Best trial achieved validation accuracy: {best_accuracy}")
# Out:
# Trial no. : 06
#
# Best hyperparameters:
# filters_1: 576
# kernel_size_1: 3
# filters_2: 32
# kernel_size_2: 3
# filters_3: 64
# kernel_size_3: 3
# filters_4: 512
# kernel_size_4: 2
# filters_5: 896
# kernel_size_5: 3
# filters_6: 896
# kernel_size_6: 3
# filters_7: 512
# kernel_size_7: 3
# l2_reg_7: 2.621394844676562e-05
# filters_8: 1280
# kernel_size_8: 3
# l2_reg_8: 0.0026239730242428264
# filters_9: 3072
# kernel_size_9: 5
# l2_reg_9: 0.00125003485633568
# filters_10: 2048
# kernel_size_10: 4
# l2_reg_10: 0.003648487673139326
# units_1: 1664
# units_2: 768
# dropout_1: 0.4
# units_3: 1408
# dropout_2: 0.2
# learning_rate: 0.0001
#
# Best trial achieved validation accuracy: 0.7283582091331482

# %%
# Summary of the best model
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_50 (Conv2D)                   │ (None, 28, 28, 576)         │          16,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_50               │ (None, 28, 28, 576)         │           2,304 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_51 (Conv2D)                   │ (None, 28, 28, 32)          │         165,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_51               │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_52 (Conv2D)                   │ (None, 28, 28, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_52               │ (None, 28, 28, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_53 (Conv2D)                   │ (None, 28, 28, 512)         │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_53               │ (None, 28, 28, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_54 (Conv2D)                   │ (None, 28, 28, 896)         │       4,129,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_54               │ (None, 28, 28, 896)         │           3,584 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_55 (Conv2D)                   │ (None, 28, 28, 896)         │       7,226,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_55               │ (None, 28, 28, 896)         │           3,584 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 14, 14, 896)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_56 (Conv2D)                   │ (None, 14, 14, 512)         │       4,129,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_56               │ (None, 14, 14, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_57 (Conv2D)                   │ (None, 14, 14, 1280)        │       5,899,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_57               │ (None, 14, 14, 1280)        │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_58 (Conv2D)                   │ (None, 14, 14, 3072)        │      98,307,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_58               │ (None, 14, 14, 3072)        │          12,288 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_59 (Conv2D)                   │ (None, 14, 14, 2048)        │     100,665,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_59               │ (None, 14, 14, 2048)        │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 7, 7, 2048)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1664)                │     166,987,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 768)                 │       1,278,720 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 768)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 1408)                │       1,082,752 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 1408)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 5)                   │           7,045 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 390,084,709 (1.45 GB)
#  Trainable params: 390,064,933 (1.45 GB)
#  Non-trainable params: 19,776 (77.25 KB)

# %%
import os
import numpy as np
from tensorflow.keras.callbacks import LambdaCallback, ModelCheckpoint
import tensorflow.keras as keras

# Function to save the current epoch number to a file
def save_epoch(filepath):
    def callback(epoch, logs=None):
        print(f"[DEBUG] Saving epoch {epoch + 1}")
        with open(filepath, 'w') as f:
            f.write(str(epoch + 1))
    return LambdaCallback(on_epoch_end=callback)

# Path to save the epoch number
epoch_file = 'epoch.txt'

# Create the callback for saving the current epoch
epoch_saver = save_epoch(epoch_file)

# Define the ModelCheckpoint callback to save the best model weights
best_epoch_filepath = 'best.weights.h5'  # Save the best weights
best_epoch = ModelCheckpoint(filepath=best_epoch_filepath, 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=True,
                             mode='min', 
                             verbose=1)

# Save the entire model at each epoch
model_checkpoint_filepath = 'model.keras'  # Save the full model
model_checkpoint = ModelCheckpoint(filepath=model_checkpoint_filepath,
                                   save_weights_only=False,  # Save the entire model
                                   save_best_only=False,  # Save every epoch
                                   mode='auto',
                                   verbose=1)

# Load the last epoch number if it exists
if os.path.exists(epoch_file):
    with open(epoch_file, 'r') as f:
        last_epoch_str = f.read().strip()  # Remove leading/trailing whitespace
    if last_epoch_str:
        last_epoch = int(last_epoch_str)
    else:
        last_epoch = 0  # Default to 0 if the file is empty
else:
    last_epoch = 0  # Default to 0 if the file does not exist

# Load the entire model if a checkpoint exists
if os.path.exists(model_checkpoint_filepath):
    model = keras.models.load_model(model_checkpoint_filepath)
    print("[INFO] Model found")
else:
    print("[INFO] No model found")


# Load the best weights
if os.path.exists(best_epoch_filepath):
    model.load_weights(best_epoch_filepath)
    print("[INFO] Best Weights found")
else:
    print("[INFO] No best weights found")

if last_epoch == 0:
    print("[INFO] Starting the training, starting from scratch.")
else:
    print(f"[INFO] Continuing training network from epoch {last_epoch}...")

# Training
try:
    cnn = model.fit(x=aug.flow(trainx, trainy, batch_size=32),
                    validation_data=(testx, testy), 
                    steps_per_epoch=len(trainx) // 32,
                    initial_epoch=last_epoch,  # Start from the last epoch
                    epochs=200,  # Specify the total number of epochs
                    verbose=1,
                    callbacks=[best_epoch, model_checkpoint, epoch_saver])
except Exception as e:
    print(f"[ERROR] An error occurred during training: {e}")
# Out:
# [INFO] No model found
# [INFO] No best weights found, starting from scratch.
# [INFO] Starting the training
# Epoch 1/200
#  1/30 ━━━━━━━━━━━━━━━━━━━━ 26:28 55s/step - accuracy: 0.0938 - loss: 15.8389
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 70
#      68 # Training
#      69 try:
# ---> 70     cnn = model.fit(x=aug.flow(trainx, trainy, batch_size=32),
#      71                     validation_data=(testx, testy),
#      72                     steps_per_epoch=len(trainx) // 32,
#      73                     initial_epoch=last_epoch,  # Start from the last epoch
#      74                     epochs=200,  # Specify the total number of epochs
#      75                     verbose=1,
#      76                     callbacks=[best_epoch, model_checkpoint, epoch_saver])
#      77 except Exception as e:
#      78     print(f"[ERROR] An error occurred during training: {e}")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model
model = load_model('final_model.keras')

# %%
import gradio as gr

def predict_image(image):
    # Pre-process the image for classification
    image = cv2.resize(image, (28, 28))
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
        
    preds = model.predict(image)[0]
    class_labels = ["Bear","Elephant","Horse","Panda","Tiger"]
    result = class_labels[np.argmax(preds)]
#       "probabilities": {label: round(float(prob), 3) for label, prob in zip(class_labels, preds)}
   
    return result
outputs=gr.Textbox(label="Animal class")
# Create Gradio interfaces for both models
cnn_interface = gr.Interface(fn=predict_image, inputs="image", outputs=outputs , live=True)

# Function to run prediction asynchronously
def run_prediction_async(interface):
    interface.launch(share=True)

# Launch the interface asynchronously
thread = threading.Thread(target=run_prediction_async, args=(cnn_interface,))
thread.start()
# Out:
# Running on local URL:  http://127.0.0.1:7862
# Running on public URL: https://8d61734fe2407b2831.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8d61734fe2407b2831.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 12, in predict_image
#     result = class_labels[np.argmax(preds)]
#              ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 12, in predict_image
#     result = class_labels[np.argmax(preds)]
#              ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Traceback (most recent call last):
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1923, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\anaconda3\Lib\site-packages\gradio\utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raj Rohra\AppData\Local\Temp\ipykernel_42520\520869928.py", line 5, in predict_image
#     image = cv2.resize(image, (28, 28))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step

# %%
# Out:
# imarticus
